# %% [markdown]
# # Pandas Deep Dive
#
# ## Outline
#
#
# * Basic Data Exploration
# * Missing Values
# * Duplicates
# * Selecting / Dropping Columns
# * String operations on whole columns
# * Column splits/transformations
# * Querying a Dataframe
# * `DataFrame.at()` vs. `DataFrame.loc`
# * Joins
# * Sorting
# * Column / Row Concatenation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Making copy of data

# %% [markdown]
# It is imporatant to make a copy of data first, as in future if we corrupt the df by accident then we must have a copy to read data.

# %%
data = pd.read_csv('startup_funding.csv',thousands=',')
df = data.copy()

# %%
df
# Out:
#       index  SNo        Date   StartupName   IndustryVertical  \
# 0         0    0  01/08/2017      TouchKin         Technology
# 1         1    1  02/08/2017       Ethinos         Technology
# 2         2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3         3    3  02/08/2017          Zepo  Consumer Internet
# 4         4    4  02/08/2017  Click2Clinic  Consumer Internet
# ...     ...  ...         ...           ...                ...
# 2417     45   45  28/07/2017       Jhakaas  Consumer Internet
# 2418     46   46  28/07/2017    BigStylist  Consumer Internet
# 2419     47   47  28/07/2017    Gympik.com  Consumer Internet
# 2420     48   48  01/06/2017       Tripeur         Technology
# 2421     49   49  02/06/2017      RentOnGo          eCommerce
#
#                                             SubVertical CityLocation  \
# 0                              Predictive Care Platform    Bangalore
# 1                              Digital Marketing Agency       Mumbai
# 2         Online platform for Higher Education Services    New Delhi
# 3                                DIY Ecommerce platform       Mumbai
# 4                         healthcare service aggregator    Hyderabad
# ...                                                 ...          ...
# 2417         App-based Aggregator of Offline Businesses       Mumbai
# 2418                        Beauty Services Marketplace       Mumbai
# 2419  online marketplace for discovering fitness cen...    bangalore
# 2420                   Mobile based travel ERP platform    Bangalore
# 2421  Online Marketplace for Renting Bikes, Electron...    Bangalore
#
#                                           InvestorsName  InvestmentType  \
# 0                                           Kae Capital  Private Equity
# 1                            Triton Investment Advisors  Private Equity
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3     Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                        Narottam Thudi, Shireesh Palle    Seed Funding
# ...                                                 ...             ...
# 2417                                       Amen Dhyllon    Seed Funding
# 2418                              Info Edge (India) Ltd  Private Equity
# 2419                                RoundGlass Partners    Seed Funding
# 2420  Grace Grace Techno Ventures LLP, Rajul Garg & ...    Seed Funding
# 2421                                  TVS Motor Company  Private Equity
#
#       AmountInUSD Remarks
# 0       1300000.0     NaN
# 1             NaN     NaN
# 2             NaN     NaN
# 3        500000.0     NaN
# 4        850000.0     NaN
# ...           ...     ...
# 2417          NaN     NaN
# 2418    1250000.0     NaN
# 2419          NaN     NaN
# 2420          NaN     NaN
# 2421          NaN     NaN
#
# [2422 rows x 11 columns]

# %% [markdown]
# ## Basic Data Exploration

# %% [markdown]
# **Getting Shape of the Data**

# %%
df.shape
# Out:
# (2422, 11)

# %% [markdown]
# There are 2422 rows and 11 columns in the data

# %% [markdown]
# **Getting a list of all columns in the dataframe**

# %%
df.columns
# Out:
# Index(['index', 'SNo', 'Date', 'StartupName', 'IndustryVertical',
#        'SubVertical', 'CityLocation', 'InvestorsName', 'InvestmentType',
#        'AmountInUSD', 'Remarks'],
#       dtype='object')

# %% [markdown]
# **Checking data types of all columns**

# %%
df.dtypes
# Out:
# index                 int64
# SNo                   int64
# Date                 object
# StartupName          object
# IndustryVertical     object
# SubVertical          object
# CityLocation         object
# InvestorsName        object
# InvestmentType       object
# AmountInUSD         float64
# Remarks              object
# dtype: object

# %% [markdown]
# **Getting top/bottom 5 values**

# %% [markdown]
# By default the df.head() will show the first five rows of the data frame.

# %%
df.head(50)
# Out:
#     index  SNo        Date            StartupName   IndustryVertical  \
# 0       0    0  01/08/2017               TouchKin         Technology
# 1       1    1  02/08/2017                Ethinos         Technology
# 2       2    2  02/08/2017           Leverage Edu  Consumer Internet
# 3       3    3  02/08/2017                   Zepo  Consumer Internet
# 4       4    4  02/08/2017           Click2Clinic  Consumer Internet
# 5       5    5  01/07/2017          Billion Loans  Consumer Internet
# 6       6    6  03/07/2017       Ecolibriumenergy         Technology
# 7       7    7  04/07/2017                  Droom          eCommerce
# 8       8    8  05/07/2017              Jumbotail          eCommerce
# 9       9    9  05/07/2017                 Moglix          eCommerce
# 10     10   10  05/07/2017             Timesaverz  Consumer Internet
# 11     11   11  06/07/2017                 Minjar         Technology
# 12     12   12  06/07/2017            MyCity4kids  Consumer Internet
# 13     13   13  07/07/2017               Clip App  Consumer Internet
# 14     14   14  07/07/2017            Upwardly.in  Consumer Internet
# 15     15   15  10/07/2017             Autorox.co         Technology
# 16     16   16  11/07/2017                 Fabogo  Consumer Internet
# 17     17   17  11/07/2017             Flickstree  Consumer Internet
# 18     18   18  11/07/2017            Design Cafe  Consumer Internet
# 19     19   19  12/07/2017               Innoviti         Technology
# 20     20   20  12/07/2017               VDeliver          Logistics
# 21     21   21  12/07/2017               Bottr.me         Technology
# 22     22   22  12/07/2017               Arcatron         Technology
# 23     23   23  14/07/2017               QwikSpec         Technology
# 24     24   24  14/07/2017                Chumbak          eCommerce
# 25     25   25  17/07/2017                Increff         Technology
# 26     26   26  17/07/2017                 Vayana         Technology
# 27     27   27  18/07/2017              MObiquest         Technology
# 28     28   28  18/07/2017                  Ambee  Consumer Internet
# 29     29   29  18/07/2017        Ideal Insurance  Consumer Internet
# 30     30   30  18/07/2017  Hypernova Interactive         Technology
# 31     31   31  19/07/2017              Rentomojo  Consumer Internet
# 32     32   32  19/07/2017                 AirCTO  Consumer Internet
# 33     33   33  19/07/2017               Playablo         Technology
# 34     34   34  20/07/2017                 Trupay         Technology
# 35     35   35  21/07/2017             Brick2Wall          eCommerce
# 36     36   36  21/07/2017            FableStreet          eCommerce
# 37     37   37  21/07/2017        Monsoon Fintech         Technology
# 38     38   38  21/07/2017              MonkeyBox  Consumer Internet
# 39     39   39  25/07/2017            Noticeboard  Consumer Internet
# 40     40   40  25/07/2017                 Byju’s  Consumer Internet
# 41     41   41  26/07/2017      Creator’s Gurukul             Others
# 42     42   42  26/07/2017             Fab Hotels  Consumer Internet
# 43     43   43  26/07/2017            ThinkerBell  Consumer Internet
# 44     44   44  27/07/2017                    1mg          eCommerce
# 45     45   45  28/07/2017                Jhakaas  Consumer Internet
# 46     46   46  28/07/2017             BigStylist  Consumer Internet
# 47     47   47  28/07/2017             Gympik.com  Consumer Internet
# 48     48   48  01/06/2017                Tripeur         Technology
# 49     49   49  02/06/2017               RentOnGo          eCommerce
#
#                                           SubVertical CityLocation  \
# 0                            Predictive Care Platform    Bangalore
# 1                            Digital Marketing Agency       Mumbai
# 2       Online platform for Higher Education Services    New Delhi
# 3                              DIY Ecommerce platform       Mumbai
# 4                       healthcare service aggregator    Hyderabad
# 5                       Peer to Peer Lending platform    Bangalore
# 6                Energy management solutions provider    Ahmedabad
# 7                  Online marketplace for automobiles      Gurgaon
# 8             online marketplace for food and grocery    Bangalore
# 9             B2B marketplace for Industrial products        Noida
# 10                  Hyperlocal home services provider       Mumbai
# 11                           Cloud Solutions provider    Bangalore
# 12  parenting blog and kids’ events discovery plat...      Gurgaon
# 13                       Digital Media Video platform    Bangalore
# 14                             MF investment platform    Bangalore
# 15              Workshop Management Software Platform    Hyderabad
# 16       Salon & Spa Aggregation & Discovery platform         Pune
# 17                   Video Content Discovery Platform       Mumbai
# 18                    Online Interior Design platform    Bangalore
# 19                         Digital payments solutions    Bangalore
# 20                        Door Step Delivery platform    Hyderabad
# 21                              Chatbot creation tool    Bangalore
# 22              Next Gen Mobility device manufacturer         Pune
# 23  Construction site operations and analytics pla...    Bangalore
# 24             Designer consumer products Marketplace    Bangalore
# 25                 Sales Solutions for Fashion Brands    Bangalore
# 26                       Enterprise Banking Solutions         Pune
# 27                        Mobile Services & Solutions        Noida
# 28                     Ambulance Aggregation Services    Hyderabad
# 29                          Online Insurance platform      Kolkata
# 30                               Mobile games creator    Bangalore
# 31                          Consumer Leasing Platform    Bangalore
# 32                    AI powered recruitment platform    Bangalore
# 33                              Gamified Learning App    Bangalore
# 34                           Online payments platform      Gurgaon
# 35       Online Marketplace for Construction Material      Gurgaon
# 36                            Women Work wear etailer    New Delhi
# 37                   Machine Learning Access platform    New Delhi
# 38                     Healthy Food Delivery Platform    Bangalore
# 39     Mobile-first Enterprise communication platform    Bangalore
# 40                                Mobile Learning App    Bangalore
# 41                          Co-Working Space Provider    New Delhi
# 42          Budget hotels brand & Aggregator Platform    New Delhi
# 43                          Assisted Learning Startup    Bangalore
# 44                                    Online Pharmacy      Gurgaon
# 45         App-based Aggregator of Offline Businesses       Mumbai
# 46                        Beauty Services Marketplace       Mumbai
# 47  online marketplace for discovering fitness cen...    bangalore
# 48                   Mobile based travel ERP platform    Bangalore
# 49  Online Marketplace for Renting Bikes, Electron...    Bangalore
#
#                                         InvestorsName  InvestmentType  \
# 0                                         Kae Capital  Private Equity
# 1                          Triton Investment Advisors  Private Equity
# 2   Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3   Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                      Narottam Thudi, Shireesh Palle    Seed Funding
# 5            Reliance Corporate Advisory Services Ltd    Seed Funding
# 6                                Infuse Ventures, JLL  Private Equity
# 7     Asset Management (Asia) Ltd, Digital Garage Inc  Private Equity
# 8       Kalaari Capital, Nexus India Capital Advisors  Private Equity
# 9   International Finance Corporation, Rocketship,...  Private Equity
# 10                                               BCCL  Private Equity
# 11  Blume Ventures, Contrarian Capital India Partn...    Seed Funding
# 12                                                NaN    Seed Funding
# 13                    India Quotient, Shunwei Capital    Seed Funding
# 14  Sreeram Iyer, Suvo Sarkar, Anita Gupta, Likemi...    Seed Funding
# 15                                       Mitsui & Co.  Private Equity
# 16                           Dunamis Ventures Pte Ltd  Private Equity
# 17  Venture Catalysts, Sourav Ganguly, Ankit Adity...    Seed Funding
# 18  Fireside Ventures, Apurva Salarpuria, Sidharth...    Seed Funding
# 19  SBI-FMO Fund, Bessemer Venture Partners, Catam...  Private Equity
# 20               Corvus Ventures, MAPE Advisory Group  Private Equity
# 21  500 Startups, Purvi Capital, Rajan Anandan, Ab...    Seed Funding
# 22                               Indian Angel Network    Seed Funding
# 23  Brigade Innovations LLP, TV Mohandas Pai, Suha...    Seed Funding
# 24                         Blacksoil Capital Pvt. Ltd  Private Equity
# 25  Sequoia Capital, Grey Orange, Rajesh Ramaiah, ...    Seed Funding
# 26       IDG Ventures India Advisors, Jungle Ventures  Private Equity
# 27                            One97 Communication Ltd  Private Equity
# 28           Uber Technologies Inc, Amaya Capital LLP    Seed Funding
# 29                                            Xelpmoc    Seed Funding
# 30                                        Kae Capital    Seed Funding
# 31             ain Capital Ventures, Renaud Laplanche  Private Equity
# 32                                     Francesco Cara    Seed Funding
# 33                          ABI-Showatech (India) Ltd    Seed Funding
# 34                         Kae Capital, M&S Partners,    Seed Funding
# 35  Subramani Somasundaram, Sundeep Sahni, Mayank ...    Seed Funding
# 36  Harmeet Bajaj, Pameela P, Fusiontech Ventures ...    Seed Funding
# 37  Sunil Kalra, Aditya Singh, Rishi Srivastava, R...    Seed Funding
# 38                Blume Ventures, NB Ventures, Nspira    Seed Funding
# 39                        Stellaris Venture Partners,  Private Equity
# 40                                   Tencent Holdings  Private Equity
# 41                                       Yuvraj Singh    Seed Funding
# 42                                      Goldman Sachs  Private Equity
# 43               Indian Angel Network, Anand Mahindra    Seed Funding
# 44  HBM Healthcare Investments, Maverick Capital V...  Private Equity
# 45                                       Amen Dhyllon    Seed Funding
# 46                              Info Edge (India) Ltd  Private Equity
# 47                                RoundGlass Partners    Seed Funding
# 48  Grace Grace Techno Ventures LLP, Rajul Garg & ...    Seed Funding
# 49                                  TVS Motor Company  Private Equity
#
#     AmountInUSD Remarks
# 0     1300000.0     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3      500000.0     NaN
# 4      850000.0     NaN
# 5     1000000.0     NaN
# 6     2600000.0     NaN
# 7    20000000.0     NaN
# 8     8500000.0     NaN
# 9    12000000.0     NaN
# 10    1000000.0     NaN
# 11          NaN     NaN
# 12          NaN     NaN
# 13    1000000.0     NaN
# 14          NaN     NaN
# 15    3000000.0     NaN
# 16    2250000.0     NaN
# 17     464000.0     NaN
# 18          NaN     NaN
# 19   18500000.0     NaN
# 20          NaN     NaN
# 21          NaN     NaN
# 22          NaN     NaN
# 23     540000.0     NaN
# 24    1700000.0     NaN
# 25    2000000.0     NaN
# 26    4000000.0     NaN
# 27          NaN     NaN
# 28          NaN     NaN
# 29          NaN     NaN
# 30          NaN     NaN
# 31   10000000.0     NaN
# 32          NaN     NaN
# 33     600000.0     NaN
# 34     700000.0     NaN
# 35     200000.0     NaN
# 36          NaN     NaN
# 37          NaN     NaN
# 38          NaN     NaN
# 39    1200000.0     NaN
# 40   35000000.0     NaN
# 41          NaN     NaN
# 42   25000000.0     NaN
# 43     200000.0     NaN
# 44   15000000.0     NaN
# 45          NaN     NaN
# 46    1250000.0     NaN
# 47          NaN     NaN
# 48          NaN     NaN
# 49          NaN     NaN

# %% [markdown]
# By default the df.tail() will show the last five rows of the data frame.

# %%
df.tail()
# Out:
#       index  SNo        Date StartupName   IndustryVertical  \
# 2417     45   45  28/07/2017     Jhakaas  Consumer Internet
# 2418     46   46  28/07/2017  BigStylist  Consumer Internet
# 2419     47   47  28/07/2017  Gympik.com  Consumer Internet
# 2420     48   48  01/06/2017     Tripeur         Technology
# 2421     49   49  02/06/2017    RentOnGo          eCommerce
#
#                                             SubVertical CityLocation  \
# 2417         App-based Aggregator of Offline Businesses       Mumbai
# 2418                        Beauty Services Marketplace       Mumbai
# 2419  online marketplace for discovering fitness cen...    bangalore
# 2420                   Mobile based travel ERP platform    Bangalore
# 2421  Online Marketplace for Renting Bikes, Electron...    Bangalore
#
#                                           InvestorsName  InvestmentType  \
# 2417                                       Amen Dhyllon    Seed Funding
# 2418                              Info Edge (India) Ltd  Private Equity
# 2419                                RoundGlass Partners    Seed Funding
# 2420  Grace Grace Techno Ventures LLP, Rajul Garg & ...    Seed Funding
# 2421                                  TVS Motor Company  Private Equity
#
#       AmountInUSD Remarks
# 2417          NaN     NaN
# 2418    1250000.0     NaN
# 2419          NaN     NaN
# 2420          NaN     NaN
# 2421          NaN     NaN

# %% [markdown]
# **Getting top/bottom n values**

# %%
df.head(3)
# Out:
#    index  SNo        Date   StartupName   IndustryVertical  \
# 0      0    0  01/08/2017      TouchKin         Technology
# 1      1    1  02/08/2017       Ethinos         Technology
# 2      2    2  02/08/2017  Leverage Edu  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
#
#    AmountInUSD Remarks
# 0    1300000.0     NaN
# 1          NaN     NaN
# 2          NaN     NaN

# %%
df.tail(7)
# Out:
#       index  SNo        Date  StartupName   IndustryVertical  \
# 2415     43   43  26/07/2017  ThinkerBell  Consumer Internet
# 2416     44   44  27/07/2017          1mg          eCommerce
# 2417     45   45  28/07/2017      Jhakaas  Consumer Internet
# 2418     46   46  28/07/2017   BigStylist  Consumer Internet
# 2419     47   47  28/07/2017   Gympik.com  Consumer Internet
# 2420     48   48  01/06/2017      Tripeur         Technology
# 2421     49   49  02/06/2017     RentOnGo          eCommerce
#
#                                             SubVertical CityLocation  \
# 2415                          Assisted Learning Startup    Bangalore
# 2416                                    Online Pharmacy      Gurgaon
# 2417         App-based Aggregator of Offline Businesses       Mumbai
# 2418                        Beauty Services Marketplace       Mumbai
# 2419  online marketplace for discovering fitness cen...    bangalore
# 2420                   Mobile based travel ERP platform    Bangalore
# 2421  Online Marketplace for Renting Bikes, Electron...    Bangalore
#
#                                           InvestorsName  InvestmentType  \
# 2415               Indian Angel Network, Anand Mahindra    Seed Funding
# 2416  HBM Healthcare Investments, Maverick Capital V...  Private Equity
# 2417                                       Amen Dhyllon    Seed Funding
# 2418                              Info Edge (India) Ltd  Private Equity
# 2419                                RoundGlass Partners    Seed Funding
# 2420  Grace Grace Techno Ventures LLP, Rajul Garg & ...    Seed Funding
# 2421                                  TVS Motor Company  Private Equity
#
#       AmountInUSD Remarks
# 2415     200000.0     NaN
# 2416   15000000.0     NaN
# 2417          NaN     NaN
# 2418    1250000.0     NaN
# 2419          NaN     NaN
# 2420          NaN     NaN
# 2421          NaN     NaN

# %% [markdown]
# **Getting a summary of all columns**

# %% [markdown]
# This will display the basic stats of the **numerical columns** in the data frame

# %%
df.describe()
# Out:
#              index          SNo   AmountInUSD
# count  2422.000000  2422.000000  1.553000e+03
# mean   1161.532205  1161.532205  1.192385e+07
# std     697.598259   697.598259  6.346680e+07
# min       0.000000     0.000000  1.600000e+04
# 25%     555.250000   555.250000  3.750000e+05
# 50%    1160.500000  1160.500000  1.100000e+06
# 75%    1765.750000  1765.750000  6.000000e+06
# max    2371.000000  2371.000000  1.400000e+09

# %% [markdown]
# This will display the basic stats of the **object type** columns in the data frame. The 'O' means object in the following code.

# %%
df.describe(include=['O'])
# Out:
#               Date StartupName   IndustryVertical      SubVertical  \
# count         2422        2422               2251             1486
# unique         701        2001                743             1364
# top     02/02/2015      Swiggy  Consumer Internet  Online Pharmacy
# freq            11           7                795               10
#
#        CityLocation          InvestorsName InvestmentType   Remarks
# count          2243                   2413           2421       419
# unique           71                   1885              7        69
# top       Bangalore  Undisclosed Investors   Seed Funding  Series A
# freq            649                     33           1300       177

# %% [markdown]
# To display all the columns at once use the following command.

# %%
df.describe(include='all')
# Out:
#               index          SNo        Date StartupName   IndustryVertical  \
# count   2422.000000  2422.000000        2422        2422               2251
# unique          NaN          NaN         701        2001                743
# top             NaN          NaN  02/02/2015      Swiggy  Consumer Internet
# freq            NaN          NaN          11           7                795
# mean    1161.532205  1161.532205         NaN         NaN                NaN
# std      697.598259   697.598259         NaN         NaN                NaN
# min        0.000000     0.000000         NaN         NaN                NaN
# 25%      555.250000   555.250000         NaN         NaN                NaN
# 50%     1160.500000  1160.500000         NaN         NaN                NaN
# 75%     1765.750000  1765.750000         NaN         NaN                NaN
# max     2371.000000  2371.000000         NaN         NaN                NaN
#
#             SubVertical CityLocation          InvestorsName InvestmentType  \
# count              1486         2243                   2413           2421
# unique             1364           71                   1885              7
# top     Online Pharmacy    Bangalore  Undisclosed Investors   Seed Funding
# freq                 10          649                     33           1300
# mean                NaN          NaN                    NaN            NaN
# std                 NaN          NaN                    NaN            NaN
# min                 NaN          NaN                    NaN            NaN
# 25%                 NaN          NaN                    NaN            NaN
# 50%                 NaN          NaN                    NaN            NaN
# 75%                 NaN          NaN                    NaN            NaN
# max                 NaN          NaN                    NaN            NaN
#
#          AmountInUSD   Remarks
# count   1.553000e+03       419
# unique           NaN        69
# top              NaN  Series A
# freq             NaN       177
# mean    1.192385e+07       NaN
# std     6.346680e+07       NaN
# min     1.600000e+04       NaN
# 25%     3.750000e+05       NaN
# 50%     1.100000e+06       NaN
# 75%     6.000000e+06       NaN
# max     1.400000e+09       NaN

# %% [markdown]
# **Getting unique values of  single column**

# %% [markdown]
# After running this command you will see that it returns all unique values that are present in the column **InvestmentType**.
#
# Note that **PrivateEquity** and **Private Equity** are two unique values.

# %%
df['InvestmentType'].unique()
# Out:
# array(['Private Equity', 'Seed Funding', 'Debt Funding', nan,
#        'SeedFunding', 'PrivateEquity', 'Crowd funding', 'Crowd Funding'],
#       dtype=object)

# %% [markdown]
# ## Missing Values

# %% [markdown]
# **Checking which columns have missing values and how many**

# %%
df.isnull().sum()
# Out:
# index                  0
# SNo                    0
# Date                   0
# StartupName            0
# IndustryVertical     171
# SubVertical          936
# CityLocation         179
# InvestorsName          9
# InvestmentType         1
# AmountInUSD          869
# Remarks             2003
# dtype: int64

# %% [markdown]
# **Treating Missing Values of a single column (Series)**

# %%
df['AmountInUSD'] = df['AmountInUSD'].fillna(0)

# %% [markdown]
# After running the following command you'll see that AmountInUSD is now filled with 0 and it doesn't have any missing/null values.

# %%
df.isnull().sum()
# Out:
# index                  0
# SNo                    0
# Date                   0
# StartupName            0
# IndustryVertical     171
# SubVertical          936
# CityLocation         179
# InvestorsName          9
# InvestmentType         1
# AmountInUSD            0
# Remarks             2003
# dtype: int64

# %% [markdown]
# **Treating all Missing Values at once**

# %%
df.fillna('Others', inplace=True)

# %% [markdown]
# The **inplace=True** parameter in the above code acts like an assignment operator and re-assigns the the changed changed df.

# %%
df.isnull().sum()
# Out:
# index               0
# SNo                 0
# Date                0
# StartupName         0
# IndustryVertical    0
# SubVertical         0
# CityLocation        0
# InvestorsName       0
# InvestmentType      0
# AmountInUSD         0
# Remarks             0
# dtype: int64

# %% [markdown]
# Now you can see that all the columns have no **0** or **null values**

# %% [markdown]
# ## Duplicates

# %% [markdown]
# **Checking for duplicates in a specefic column**

# %%
df.duplicated(['StartupName']).sum()
# Out:
# 421

# %% [markdown]
# This means that there are **421** StartupName instances that are exactly the same.

# %% [markdown]
# **Checking for whole row duplicates**

# %%
df.duplicated().sum()
# Out:
# 50

# %% [markdown]
# this returns the total number of rows that are duplicated.

# %%
df[df.duplicated()]
# Out:
#       index  SNo        Date            StartupName   IndustryVertical  \
# 2372      0    0  01/08/2017               TouchKin         Technology
# 2373      1    1  02/08/2017                Ethinos         Technology
# 2374      2    2  02/08/2017           Leverage Edu  Consumer Internet
# 2375      3    3  02/08/2017                   Zepo  Consumer Internet
# 2376      4    4  02/08/2017           Click2Clinic  Consumer Internet
# 2377      5    5  01/07/2017          Billion Loans  Consumer Internet
# 2378      6    6  03/07/2017       Ecolibriumenergy         Technology
# 2379      7    7  04/07/2017                  Droom          eCommerce
# 2380      8    8  05/07/2017              Jumbotail          eCommerce
# 2381      9    9  05/07/2017                 Moglix          eCommerce
# 2382     10   10  05/07/2017             Timesaverz  Consumer Internet
# 2383     11   11  06/07/2017                 Minjar         Technology
# 2384     12   12  06/07/2017            MyCity4kids  Consumer Internet
# 2385     13   13  07/07/2017               Clip App  Consumer Internet
# 2386     14   14  07/07/2017            Upwardly.in  Consumer Internet
# 2387     15   15  10/07/2017             Autorox.co         Technology
# 2388     16   16  11/07/2017                 Fabogo  Consumer Internet
# 2389     17   17  11/07/2017             Flickstree  Consumer Internet
# 2390     18   18  11/07/2017            Design Cafe  Consumer Internet
# 2391     19   19  12/07/2017               Innoviti         Technology
# 2392     20   20  12/07/2017               VDeliver          Logistics
# 2393     21   21  12/07/2017               Bottr.me         Technology
# 2394     22   22  12/07/2017               Arcatron         Technology
# 2395     23   23  14/07/2017               QwikSpec         Technology
# 2396     24   24  14/07/2017                Chumbak          eCommerce
# 2397     25   25  17/07/2017                Increff         Technology
# 2398     26   26  17/07/2017                 Vayana         Technology
# 2399     27   27  18/07/2017              MObiquest         Technology
# 2400     28   28  18/07/2017                  Ambee  Consumer Internet
# 2401     29   29  18/07/2017        Ideal Insurance  Consumer Internet
# 2402     30   30  18/07/2017  Hypernova Interactive         Technology
# 2403     31   31  19/07/2017              Rentomojo  Consumer Internet
# 2404     32   32  19/07/2017                 AirCTO  Consumer Internet
# 2405     33   33  19/07/2017               Playablo         Technology
# 2406     34   34  20/07/2017                 Trupay         Technology
# 2407     35   35  21/07/2017             Brick2Wall          eCommerce
# 2408     36   36  21/07/2017            FableStreet          eCommerce
# 2409     37   37  21/07/2017        Monsoon Fintech         Technology
# 2410     38   38  21/07/2017              MonkeyBox  Consumer Internet
# 2411     39   39  25/07/2017            Noticeboard  Consumer Internet
# 2412     40   40  25/07/2017                 Byju’s  Consumer Internet
# 2413     41   41  26/07/2017      Creator’s Gurukul             Others
# 2414     42   42  26/07/2017             Fab Hotels  Consumer Internet
# 2415     43   43  26/07/2017            ThinkerBell  Consumer Internet
# 2416     44   44  27/07/2017                    1mg          eCommerce
# 2417     45   45  28/07/2017                Jhakaas  Consumer Internet
# 2418     46   46  28/07/2017             BigStylist  Consumer Internet
# 2419     47   47  28/07/2017             Gympik.com  Consumer Internet
# 2420     48   48  01/06/2017                Tripeur         Technology
# 2421     49   49  02/06/2017               RentOnGo          eCommerce
#
#                                             SubVertical CityLocation  \
# 2372                           Predictive Care Platform    Bangalore
# 2373                           Digital Marketing Agency       Mumbai
# 2374      Online platform for Higher Education Services    New Delhi
# 2375                             DIY Ecommerce platform       Mumbai
# 2376                      healthcare service aggregator    Hyderabad
# 2377                      Peer to Peer Lending platform    Bangalore
# 2378               Energy management solutions provider    Ahmedabad
# 2379                 Online marketplace for automobiles      Gurgaon
# 2380            online marketplace for food and grocery    Bangalore
# 2381            B2B marketplace for Industrial products        Noida
# 2382                  Hyperlocal home services provider       Mumbai
# 2383                           Cloud Solutions provider    Bangalore
# 2384  parenting blog and kids’ events discovery plat...      Gurgaon
# 2385                       Digital Media Video platform    Bangalore
# 2386                             MF investment platform    Bangalore
# 2387              Workshop Management Software Platform    Hyderabad
# 2388       Salon & Spa Aggregation & Discovery platform         Pune
# 2389                   Video Content Discovery Platform       Mumbai
# 2390                    Online Interior Design platform    Bangalore
# 2391                         Digital payments solutions    Bangalore
# 2392                        Door Step Delivery platform    Hyderabad
# 2393                              Chatbot creation tool    Bangalore
# 2394              Next Gen Mobility device manufacturer         Pune
# 2395  Construction site operations and analytics pla...    Bangalore
# 2396             Designer consumer products Marketplace    Bangalore
# 2397                 Sales Solutions for Fashion Brands    Bangalore
# 2398                       Enterprise Banking Solutions         Pune
# 2399                        Mobile Services & Solutions        Noida
# 2400                     Ambulance Aggregation Services    Hyderabad
# 2401                          Online Insurance platform      Kolkata
# 2402                               Mobile games creator    Bangalore
# 2403                          Consumer Leasing Platform    Bangalore
# 2404                    AI powered recruitment platform    Bangalore
# 2405                              Gamified Learning App    Bangalore
# 2406                           Online payments platform      Gurgaon
# 2407       Online Marketplace for Construction Material      Gurgaon
# 2408                            Women Work wear etailer    New Delhi
# 2409                   Machine Learning Access platform    New Delhi
# 2410                     Healthy Food Delivery Platform    Bangalore
# 2411     Mobile-first Enterprise communication platform    Bangalore
# 2412                                Mobile Learning App    Bangalore
# 2413                          Co-Working Space Provider    New Delhi
# 2414          Budget hotels brand & Aggregator Platform    New Delhi
# 2415                          Assisted Learning Startup    Bangalore
# 2416                                    Online Pharmacy      Gurgaon
# 2417         App-based Aggregator of Offline Businesses       Mumbai
# 2418                        Beauty Services Marketplace       Mumbai
# 2419  online marketplace for discovering fitness cen...    bangalore
# 2420                   Mobile based travel ERP platform    Bangalore
# 2421  Online Marketplace for Renting Bikes, Electron...    Bangalore
#
#                                           InvestorsName  InvestmentType  \
# 2372                                        Kae Capital  Private Equity
# 2373                         Triton Investment Advisors  Private Equity
# 2374  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 2375  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 2376                     Narottam Thudi, Shireesh Palle    Seed Funding
# 2377           Reliance Corporate Advisory Services Ltd    Seed Funding
# 2378                               Infuse Ventures, JLL  Private Equity
# 2379    Asset Management (Asia) Ltd, Digital Garage Inc  Private Equity
# 2380      Kalaari Capital, Nexus India Capital Advisors  Private Equity
# 2381  International Finance Corporation, Rocketship,...  Private Equity
# 2382                                               BCCL  Private Equity
# 2383  Blume Ventures, Contrarian Capital India Partn...    Seed Funding
# 2384                                             Others    Seed Funding
# 2385                    India Quotient, Shunwei Capital    Seed Funding
# 2386  Sreeram Iyer, Suvo Sarkar, Anita Gupta, Likemi...    Seed Funding
# 2387                                       Mitsui & Co.  Private Equity
# 2388                           Dunamis Ventures Pte Ltd  Private Equity
# 2389  Venture Catalysts, Sourav Ganguly, Ankit Adity...    Seed Funding
# 2390  Fireside Ventures, Apurva Salarpuria, Sidharth...    Seed Funding
# 2391  SBI-FMO Fund, Bessemer Venture Partners, Catam...  Private Equity
# 2392               Corvus Ventures, MAPE Advisory Group  Private Equity
# 2393  500 Startups, Purvi Capital, Rajan Anandan, Ab...    Seed Funding
# 2394                               Indian Angel Network    Seed Funding
# 2395  Brigade Innovations LLP, TV Mohandas Pai, Suha...    Seed Funding
# 2396                         Blacksoil Capital Pvt. Ltd  Private Equity
# 2397  Sequoia Capital, Grey Orange, Rajesh Ramaiah, ...    Seed Funding
# 2398       IDG Ventures India Advisors, Jungle Ventures  Private Equity
# 2399                            One97 Communication Ltd  Private Equity
# 2400           Uber Technologies Inc, Amaya Capital LLP    Seed Funding
# 2401                                            Xelpmoc    Seed Funding
# 2402                                        Kae Capital    Seed Funding
# 2403             ain Capital Ventures, Renaud Laplanche  Private Equity
# 2404                                     Francesco Cara    Seed Funding
# 2405                          ABI-Showatech (India) Ltd    Seed Funding
# 2406                         Kae Capital, M&S Partners,    Seed Funding
# 2407  Subramani Somasundaram, Sundeep Sahni, Mayank ...    Seed Funding
# 2408  Harmeet Bajaj, Pameela P, Fusiontech Ventures ...    Seed Funding
# 2409  Sunil Kalra, Aditya Singh, Rishi Srivastava, R...    Seed Funding
# 2410                Blume Ventures, NB Ventures, Nspira    Seed Funding
# 2411                        Stellaris Venture Partners,  Private Equity
# 2412                                   Tencent Holdings  Private Equity
# 2413                                       Yuvraj Singh    Seed Funding
# 2414                                      Goldman Sachs  Private Equity
# 2415               Indian Angel Network, Anand Mahindra    Seed Funding
# 2416  HBM Healthcare Investments, Maverick Capital V...  Private Equity
# 2417                                       Amen Dhyllon    Seed Funding
# 2418                              Info Edge (India) Ltd  Private Equity
# 2419                                RoundGlass Partners    Seed Funding
# 2420  Grace Grace Techno Ventures LLP, Rajul Garg & ...    Seed Funding
# 2421                                  TVS Motor Company  Private Equity
#
#       AmountInUSD Remarks
# 2372    1300000.0  Others
# 2373          0.0  Others
# 2374          0.0  Others
# 2375     500000.0  Others
# 2376     850000.0  Others
# 2377    1000000.0  Others
# 2378    2600000.0  Others
# 2379   20000000.0  Others
# 2380    8500000.0  Others
# 2381   12000000.0  Others
# 2382    1000000.0  Others
# 2383          0.0  Others
# 2384          0.0  Others
# 2385    1000000.0  Others
# 2386          0.0  Others
# 2387    3000000.0  Others
# 2388    2250000.0  Others
# 2389     464000.0  Others
# 2390          0.0  Others
# 2391   18500000.0  Others
# 2392          0.0  Others
# 2393          0.0  Others
# 2394          0.0  Others
# 2395     540000.0  Others
# 2396    1700000.0  Others
# 2397    2000000.0  Others
# 2398    4000000.0  Others
# 2399          0.0  Others
# 2400          0.0  Others
# 2401          0.0  Others
# 2402          0.0  Others
# 2403   10000000.0  Others
# 2404          0.0  Others
# 2405     600000.0  Others
# 2406     700000.0  Others
# 2407     200000.0  Others
# 2408          0.0  Others
# 2409          0.0  Others
# 2410          0.0  Others
# 2411    1200000.0  Others
# 2412   35000000.0  Others
# 2413          0.0  Others
# 2414   25000000.0  Others
# 2415     200000.0  Others
# 2416   15000000.0  Others
# 2417          0.0  Others
# 2418    1250000.0  Others
# 2419          0.0  Others
# 2420          0.0  Others
# 2421          0.0  Others

# %% [markdown]
# This shows that these are the rows that are duplicated. They may have more than 2 instances.

# %% [markdown]
# **Deleting duplicates from a specefic column**

# %%
df.shape
# Out:
# (2422, 11)

# %% [markdown]
# Following code will delete the duplicates that are present in **StartupName**. The **keep='First'** parameter keeps the first occurance of the instance that is duplicated and deletes the rest. So in resutl only unique instances are left

# %%
df.drop_duplicates(['StartupName'], keep='first').shape # Default is keep=first
# Out:
# (2001, 11)

# %%
df.drop_duplicates(['StartupName'], keep='last').shape #keep=last keeps the last instance and deletes the rest
# Out:
# (2001, 11)

# %%
df.drop_duplicates(['StartupName'], keep=False).shape # this deletes all the occurances of the duplicates so none is left.
# Out:
# (1679, 11)

# %% [markdown]
# **NOTE:** In all the above occurances neither did we use the inplace=True parameter nor manually assigned it. So there won't be any change in the df

# %% [markdown]
# **Deleting whole row duplicates**

# %%
df.drop_duplicates().shape
# Out:
# (2372, 11)

# %%
df.shape
# Out:
# (2422, 11)

# %% [markdown]
# Now we will use the inplace=True parameter to save the data frame

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (2372, 11)

# %% [markdown]
# ## Selecting / Dropping Columns

# %% [markdown]
# **Selecting Columns**

# %% [markdown]
# In order to select multiple columns we have to pass their names as list in the data frame

# %%
df[['Date', 'CityLocation', 'AmountInUSD']]
# Out:
#             Date CityLocation  AmountInUSD
# 0     01/08/2017    Bangalore    1300000.0
# 1     02/08/2017       Mumbai          0.0
# 2     02/08/2017    New Delhi          0.0
# 3     02/08/2017       Mumbai     500000.0
# 4     02/08/2017    Hyderabad     850000.0
# ...          ...          ...          ...
# 2367  29/01/2015       Others    4500000.0
# 2368  29/01/2015       Others     825000.0
# 2369  30/01/2015       Others    1500000.0
# 2370  30/01/2015       Others          0.0
# 2371  31/01/2015       Others     140000.0
#
# [2372 rows x 3 columns]

# %% [markdown]
# **Dropping Columns**

# %%
df.head()
# Out:
#    index  SNo        Date   StartupName   IndustryVertical  \
# 0      0    0  01/08/2017      TouchKin         Technology
# 1      1    1  02/08/2017       Ethinos         Technology
# 2      2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3      3    3  02/08/2017          Zepo  Consumer Internet
# 4      4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#    AmountInUSD Remarks
# 0    1300000.0  Others
# 1          0.0  Others
# 2          0.0  Others
# 3     500000.0  Others
# 4     850000.0  Others

# %%
df.drop('index', axis=1).shape
# Out:
# (2372, 10)

# %%
df.shape
# Out:
# (2372, 11)

# %% [markdown]
# use the inplace true paramter to save the data frame

# %%
df.drop('index', axis=1,inplace=True)

# %%
df.shape
# Out:
# (2372, 10)

# %%
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#    AmountInUSD Remarks
# 0    1300000.0  Others
# 1          0.0  Others
# 2          0.0  Others
# 3     500000.0  Others
# 4     850000.0  Others

# %% [markdown]
# ## String Operations on whole columns

# %% [markdown]
# **String Replacement**

# %%
df['InvestmentType'].unique()
# Out:
# array(['Private Equity', 'Seed Funding', 'Debt Funding', 'Others',
#        'SeedFunding', 'PrivateEquity', 'Crowd funding', 'Crowd Funding'],
#       dtype=object)

# %% [markdown]
# We want to replace *PrivateEquatiy* which is written together to be written as *Private Equatiy*

# %%
# first parameter in str.replace is the one which we want to replace and
#the second one is with which we are replacing it
df['InvestmentType'].replace('PrivateEquity', 'Private Equity').unique()
# Out:
# array(['Private Equity', 'Seed Funding', 'Debt Funding', 'Others',
#        'SeedFunding', 'Crowd funding', 'Crowd Funding'], dtype=object)

# %%
df['InvestmentType'].unique()
# Out:
# array(['Private Equity', 'Seed Funding', 'Debt Funding', 'Others',
#        'SeedFunding', 'PrivateEquity', 'Crowd funding', 'Crowd Funding'],
#       dtype=object)

# %% [markdown]
# As you can see it is back in the df because we did not re assign it. **Inplace=True** does **NOT** work here so we have to reassign it manually

# %%
df['InvestmentType'] = df['InvestmentType'].str.replace('PrivateEquity', 'Private Equity')
df['InvestmentType'] = df['InvestmentType'].str.replace('SeedFunding', 'Seed Funding')
df['InvestmentType'] = df['InvestmentType'].str.replace('Crowd funding', 'Crowd Funding')

# %%
df['InvestmentType'].unique()
# Out:
# array(['Private Equity', 'Seed Funding', 'Debt Funding', 'Others',
#        'Crowd Funding'], dtype=object)

# %% [markdown]
# **Capitalization**

# %% [markdown]
# To capitalize every name in a specific column use the follwing code

# %%
df['CityLocation'].str.lower()
# Out:
# 0       bangalore
# 1          mumbai
# 2       new delhi
# 3          mumbai
# 4       hyderabad
#           ...
# 2367       others
# 2368       others
# 2369       others
# 2370       others
# 2371       others
# Name: CityLocation, Length: 2372, dtype: object

# %% [markdown]
# **Checking if there is a substring in each column value**

# %%
df[df['InvestorsName'].str.contains('Khan')]
# Out:
#        SNo        Date         StartupName                 IndustryVertical  \
# 81      81  16/06/2017             Fincash                Consumer Internet
# 780    780  17/08/2016           MaalGaadi                        Logistics
# 871    871  15/07/2016             BaggOut                        eCommerce
# 920    920  10/06/2016      Kickstart Jobs                       Technology
# 947    947  17/06/2016                 BYG                Consumer Internet
# 1094  1094  13/04/2016         Legalraasta                Consumer Internet
# 1155  1155   03/3/2016  Imarticus Learning                        Education
# 1581  1581  19/11/2015       PlaceofOrigin  Online Gourmet Food Marketplace
# 1598  1598  25/11/2015              Tooler   On Demand Laundry Services App
# 1793  1793  29/09/2015          LoanCircle     Consumer lending marketplace
# 1905  1905  02/07/2015             Zenatix      Internet of Things platform
#
#                                             SubVertical CityLocation  \
# 81                            Personal Finance platform       Mumbai
# 780                        Online Logistics Marketplace       Indore
# 871                             Women’s Fashion etailer    New Delhi
# 920                         Entry level hiring platform      Gurgaon
# 947       Fitness centre Discovery & Booking Mobile app    Bangalore
# 1094                 Online legal Services for Startups    New Delhi
# 1155  Financial Services & Analytics Education Insti...       Mumbai
# 1581                                             Others    Bangalore
# 1598                                             Others    New Delhi
# 1793                                             Others    Bangalore
# 1905                                             Others      Gurgaon
#
#                                           InvestorsName  InvestmentType  \
# 81               Mohammed Khan, Sameer Narayan & Others    Seed Funding
# 780     Swan Angel Network,Sachin Khandelwal and others    Seed Funding
# 871   Sumit Jain, Sumit Jain, Anurag Gupta, Varun Kh...    Seed Funding
# 920   Vivek Joshi, Mohit Satyanand, Amit Banati, Aru...    Seed Funding
# 947             Sanjay Verma, Amit Khanna (LetsVenture)    Seed Funding
# 1094                Pravin Khandelwal, Yatin Kumar Jain    Seed Funding
# 1155  Blinc Advisors, Amit Nanavati, Tashwinder Sing...  Private Equity
# 1581  S.D. Shibulal, Kris Gopalakrishnan, Srinath Ba...    Seed Funding
# 1598                         Raghu Khanna, Sameer Gupta    Seed Funding
# 1793              Zishaan Hayath, Rahul Khanna & Others    Seed Funding
# 1905  Rajan Anandan, Kunal Bahl, Rohit Bansal, Rahul...    Seed Funding
#
#       AmountInUSD Remarks
# 81       100000.0  Others
# 780      375000.0  Others
# 871           0.0  Others
# 920           0.0  Others
# 947           0.0  Others
# 1094    1000000.0  Others
# 1155    1000000.0  Others
# 1581          0.0  Others
# 1598     110000.0  Others
# 1793          0.0  Others
# 1905     161000.0  Others

# %%
df[df['InvestorsName'].str.contains(' Khan')]
# Out:
#        SNo        Date         StartupName                 IndustryVertical  \
# 81      81  16/06/2017             Fincash                Consumer Internet
# 780    780  17/08/2016           MaalGaadi                        Logistics
# 871    871  15/07/2016             BaggOut                        eCommerce
# 920    920  10/06/2016      Kickstart Jobs                       Technology
# 947    947  17/06/2016                 BYG                Consumer Internet
# 1094  1094  13/04/2016         Legalraasta                Consumer Internet
# 1155  1155   03/3/2016  Imarticus Learning                        Education
# 1581  1581  19/11/2015       PlaceofOrigin  Online Gourmet Food Marketplace
# 1598  1598  25/11/2015              Tooler   On Demand Laundry Services App
# 1793  1793  29/09/2015          LoanCircle     Consumer lending marketplace
# 1905  1905  02/07/2015             Zenatix      Internet of Things platform
#
#                                             SubVertical CityLocation  \
# 81                            Personal Finance platform       Mumbai
# 780                        Online Logistics Marketplace       Indore
# 871                             Women’s Fashion etailer    New Delhi
# 920                         Entry level hiring platform      Gurgaon
# 947       Fitness centre Discovery & Booking Mobile app    Bangalore
# 1094                 Online legal Services for Startups    New Delhi
# 1155  Financial Services & Analytics Education Insti...       Mumbai
# 1581                                             Others    Bangalore
# 1598                                             Others    New Delhi
# 1793                                             Others    Bangalore
# 1905                                             Others      Gurgaon
#
#                                           InvestorsName  InvestmentType  \
# 81               Mohammed Khan, Sameer Narayan & Others    Seed Funding
# 780     Swan Angel Network,Sachin Khandelwal and others    Seed Funding
# 871   Sumit Jain, Sumit Jain, Anurag Gupta, Varun Kh...    Seed Funding
# 920   Vivek Joshi, Mohit Satyanand, Amit Banati, Aru...    Seed Funding
# 947             Sanjay Verma, Amit Khanna (LetsVenture)    Seed Funding
# 1094                Pravin Khandelwal, Yatin Kumar Jain    Seed Funding
# 1155  Blinc Advisors, Amit Nanavati, Tashwinder Sing...  Private Equity
# 1581  S.D. Shibulal, Kris Gopalakrishnan, Srinath Ba...    Seed Funding
# 1598                         Raghu Khanna, Sameer Gupta    Seed Funding
# 1793              Zishaan Hayath, Rahul Khanna & Others    Seed Funding
# 1905  Rajan Anandan, Kunal Bahl, Rohit Bansal, Rahul...    Seed Funding
#
#       AmountInUSD Remarks
# 81       100000.0  Others
# 780      375000.0  Others
# 871           0.0  Others
# 920           0.0  Others
# 947           0.0  Others
# 1094    1000000.0  Others
# 1155    1000000.0  Others
# 1581          0.0  Others
# 1598     110000.0  Others
# 1793          0.0  Others
# 1905     161000.0  Others

# %%
df['InvestorsName'].str.contains('Khan').sum()
# Out:
# 11

# %%
df['InvestorsName'].str.contains('khan').sum()
# Out:
# 3

# %% [markdown]
# **What do you observe?**
# <br>The str.contains() function is case sensative. If you pass Khan with capital K then it will search it with capital K otherwise if you pass lower k then it will search accordingly.

# %% [markdown]
# ## Column Transformations / Splits

# %% [markdown]
# **Changing Data types**
#
# ___1. Normal conversion___

# %%
df.dtypes
# Out:
# SNo                   int64
# Date                 object
# StartupName          object
# IndustryVertical     object
# SubVertical          object
# CityLocation         object
# InvestorsName        object
# InvestmentType       object
# AmountInUSD         float64
# Remarks              object
# dtype: object

# %%
df['AmountInUSD']=df['AmountInUSD'].astype(np.int64)

# %%
df.dtypes
# Out:
# SNo                  int64
# Date                object
# StartupName         object
# IndustryVertical    object
# SubVertical         object
# CityLocation        object
# InvestorsName       object
# InvestmentType      object
# AmountInUSD          int64
# Remarks             object
# dtype: object

# %% [markdown]
# ___2. Dates Conversion___

# %% [markdown]
# This will return an error as there are unknown string formats present. The below function will only work when date is in a specific format like 1/1/2001

# %%
#pd.to_datetime(df['Date'])

# %%
df['Date'].str.contains('//').sum()
# Out:
# 1

# %% [markdown]
# we saw in the data that there were some anomolies present. Like in the dates double slashes were used instead of single so we had to replace them
# <br> The errors='coerce' parameter ignores the errors and converts the rest.

# %%
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#    AmountInUSD Remarks
# 0      1300000  Others
# 1            0  Others
# 2            0  Others
# 3       500000  Others
# 4       850000  Others

# %%
df['New Date'] = pd.to_datetime(df['Date'].str.replace('//', '/'), dayfirst=True, errors='coerce')

# %%
df.dtypes
# Out:
# SNo                          int64
# Date                        object
# StartupName                 object
# IndustryVertical            object
# SubVertical                 object
# CityLocation                object
# InvestorsName               object
# InvestmentType              object
# AmountInUSD                  int64
# Remarks                     object
# New Date            datetime64[ns]
# dtype: object

# %%
df.isnull().sum()
# Out:
# SNo                 0
# Date                0
# StartupName         0
# IndustryVertical    0
# SubVertical         0
# CityLocation        0
# InvestorsName       0
# InvestmentType      0
# AmountInUSD         0
# Remarks             0
# New Date            0
# dtype: int64

# %%
df[df['New Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [SNo, Date, StartupName, IndustryVertical, SubVertical, CityLocation, InvestorsName, InvestmentType, AmountInUSD, Remarks, New Date]
# Index: []

# %%
df['Date']=df['Date'].str.replace('//', '/')
df['Date']=df['Date'].str.replace('.', '/')

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')

# %%
df.dtypes
# Out:
# SNo                          int64
# Date                datetime64[ns]
# StartupName                 object
# IndustryVertical            object
# SubVertical                 object
# CityLocation                object
# InvestorsName               object
# InvestmentType              object
# AmountInUSD                  int64
# Remarks                     object
# New Date            datetime64[ns]
# dtype: object

# %%
df.isnull().sum()
# Out:
# SNo                 0
# Date                0
# StartupName         0
# IndustryVertical    0
# SubVertical         0
# CityLocation        0
# InvestorsName       0
# InvestmentType      0
# AmountInUSD         0
# Remarks             0
# New Date            0
# dtype: int64

# %%
df.drop('New Date',axis=1,inplace=True)

# %% [markdown]
# **Getting months/year/days as separate columns from a datetime column**

# %%
df['month'] = pd.DatetimeIndex(df['Date']).month

# %%
df.head()
# Out:
#    SNo       Date   StartupName   IndustryVertical  \
# 0    0 2017-08-01      TouchKin         Technology
# 1    1 2017-08-02       Ethinos         Technology
# 2    2 2017-08-02  Leverage Edu  Consumer Internet
# 3    3 2017-08-02          Zepo  Consumer Internet
# 4    4 2017-08-02  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#    AmountInUSD Remarks  month
# 0      1300000  Others      8
# 1            0  Others      8
# 2            0  Others      8
# 3       500000  Others      8
# 4       850000  Others      8

# %% [markdown]
# **Exercise:** Extract day and year

# %%
df['day'] = pd.DatetimeIndex(df['Date']).day
df['year'] = pd.DatetimeIndex(df['Date']).year
df.head()
# Out:
#    SNo       Date   StartupName   IndustryVertical  \
# 0    0 2017-08-01      TouchKin         Technology
# 1    1 2017-08-02       Ethinos         Technology
# 2    2 2017-08-02  Leverage Edu  Consumer Internet
# 3    3 2017-08-02          Zepo  Consumer Internet
# 4    4 2017-08-02  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#    AmountInUSD Remarks  month  day  year
# 0      1300000  Others      8    1  2017
# 1            0  Others      8    2  2017
# 2            0  Others      8    2  2017
# 3       500000  Others      8    2  2017
# 4       850000  Others      8    2  2017

# %% [markdown]
# Extract current date time

# %%
import datetime

datetime.datetime.today()
# Out:
# datetime.datetime(2020, 12, 8, 23, 19, 8, 948473)

# %% [markdown]
# **Extracting new columns from existing string columns**

# %%
df['InvestmentType'].str.split(' ')
# Out:
# 0       [Private, Equity]
# 1       [Private, Equity]
# 2         [Seed, Funding]
# 3         [Seed, Funding]
# 4         [Seed, Funding]
#               ...
# 2367    [Private, Equity]
# 2368    [Private, Equity]
# 2369    [Private, Equity]
# 2370    [Private, Equity]
# 2371      [Seed, Funding]
# Name: InvestmentType, Length: 2372, dtype: object

# %%
df['InvestmentType'].str.split(' ').str[0].head(10)
# Out:
# 0    Private
# 1    Private
# 2       Seed
# 3       Seed
# 4       Seed
# 5       Seed
# 6    Private
# 7    Private
# 8    Private
# 9    Private
# Name: InvestmentType, dtype: object

# %% [markdown]
# ## Querying a Dataframe

# %% [markdown]
# **Querying based on a single value**

# %%
df['AmountInUSD'] < 100000
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2367    False
# 2368    False
# 2369    False
# 2370     True
# 2371    False
# Name: AmountInUSD, Length: 2372, dtype: bool

# %%
df[df['AmountInUSD'] < 100000]
# Out:
#        SNo       Date      StartupName   IndustryVertical  \
# 1        1 2017-08-02          Ethinos         Technology
# 2        2 2017-08-02     Leverage Edu  Consumer Internet
# 11      11 2017-07-06           Minjar         Technology
# 12      12 2017-07-06      MyCity4kids  Consumer Internet
# 14      14 2017-07-07      Upwardly.in  Consumer Internet
# ...    ...        ...              ...                ...
# 2355  2355 2015-05-21             Knit             Others
# 2358  2358 2015-01-22        Freshmonk             Others
# 2359  2359 2015-01-22  Englishleap.com             Others
# 2363  2363 2015-01-24         Impartus             Others
# 2370  2370 2015-01-30        Simplotel             Others
#
#                                             SubVertical CityLocation  \
# 1                              Digital Marketing Agency       Mumbai
# 2         Online platform for Higher Education Services    New Delhi
# 11                             Cloud Solutions provider    Bangalore
# 12    parenting blog and kids’ events discovery plat...      Gurgaon
# 14                               MF investment platform    Bangalore
# ...                                                 ...          ...
# 2355                                             Others       Others
# 2358                                             Others       Others
# 2359                                             Others       Others
# 2363                                             Others       Others
# 2370                                             Others       Others
#
#                                           InvestorsName  InvestmentType  \
# 1                            Triton Investment Advisors  Private Equity
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 11    Blume Ventures, Contrarian Capital India Partn...    Seed Funding
# 12                                               Others    Seed Funding
# 14    Sreeram Iyer, Suvo Sarkar, Anita Gupta, Likemi...    Seed Funding
# ...                                                 ...             ...
# 2355                  Rohit Jain, Amit Rambhia & Others    Seed Funding
# 2358            August Capital Partners, Michael Blakey    Seed Funding
# 2359                                             ANALEC  Private Equity
# 2363                              Kaizen Private Equity  Private Equity
# 2370                                         MakeMyTrip  Private Equity
#
#       AmountInUSD                            Remarks  month  day  year
# 1               0                             Others      8    2  2017
# 2               0                             Others      8    2  2017
# 11              0                             Others      7    6  2017
# 12              0                             Others      7    6  2017
# 14              0                             Others      7    7  2017
# ...           ...                                ...    ...  ...   ...
# 2355            0                             Others      5   21  2015
# 2358            0                             Others      1   22  2015
# 2359            0                     Majority Stake      1   22  2015
# 2363            0                           Series A      1   24  2015
# 2370            0  Strategic Funding, Minority stake      1   30  2015
#
# [907 rows x 13 columns]

# %% [markdown]
# **Querying based on multiple columns**

# %%
df[(df['AmountInUSD'] < 100000) & (df['CityLocation'] == 'New Delhi')]
# Out:
#        SNo       Date        StartupName                 IndustryVertical  \
# 2        2 2017-08-02       Leverage Edu                Consumer Internet
# 36      36 2017-07-21        FableStreet                        eCommerce
# 37      37 2017-07-21    Monsoon Fintech                       Technology
# 41      41 2017-07-26  Creator’s Gurukul                           Others
# 57      57 2017-06-06           GyanDhan                Consumer Internet
# ...    ...        ...                ...                              ...
# 2127  2127 2015-05-25    Newgen Payments       Payments Solution Provider
# 2175  2175 2015-04-22          FindYahan  Hyperlocal services marketplace
# 2183  2183 2015-04-23          EazyDiner       Restaurant reservation app
# 2184  2184 2015-04-23      Phone Warrior              Spam Call block App
# 2189  2189 2015-04-27              GIBBS                       Clean Tech
#
#                                         SubVertical CityLocation  \
# 2     Online platform for Higher Education Services    New Delhi
# 36                          Women Work wear etailer    New Delhi
# 37                 Machine Learning Access platform    New Delhi
# 41                        Co-Working Space Provider    New Delhi
# 57                            Education Marketplace    New Delhi
# ...                                             ...          ...
# 2127                                         Others    New Delhi
# 2175                                         Others    New Delhi
# 2183                                         Others    New Delhi
# 2184                                         Others    New Delhi
# 2189                                         Others    New Delhi
#
#                                           InvestorsName  InvestmentType  \
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 36    Harmeet Bajaj, Pameela P, Fusiontech Ventures ...    Seed Funding
# 37    Sunil Kalra, Aditya Singh, Rishi Srivastava, R...    Seed Funding
# 41                                         Yuvraj Singh    Seed Funding
# 57                            Sundaram Finance Holdings  Private Equity
# ...                                                 ...             ...
# 2127                                         Jan Manten    Seed Funding
# 2175                                   The Phoenix Fund  Private Equity
# 2183                 Deepak Shahdadpuri, Gulpreet Kohli    Seed Funding
# 2184                                Lightspeed Ventures    Seed Funding
# 2189                               Infuse Ventures fund  Private Equity
#
#       AmountInUSD       Remarks  month  day  year
# 2               0        Others      8    2  2017
# 36              0        Others      7   21  2017
# 37              0        Others      7   21  2017
# 41              0        Others      7   26  2017
# 57              0        Others      6    6  2017
# ...           ...           ...    ...  ...   ...
# 2127            0        Others      5   25  2015
# 2175            0      Series A      4   22  2015
# 2183            0        Others      4   23  2015
# 2184            0  Pre-Series A      4   23  2015
# 2189            0      Series B      4   27  2015
#
# [183 rows x 13 columns]

# %% [markdown]
# **Querying based on a list of values**

# %%
df['CityLocation'].isin(['New Delhi', 'Bangalore', 'Mumbai'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 2367    False
# 2368    False
# 2369    False
# 2370    False
# 2371    False
# Name: CityLocation, Length: 2372, dtype: bool

# %%
df[(df['CityLocation'].isin(['New Delhi', 'Bangalore', 'Mumbai'])) & (df['AmountInUSD'] < 100000)]
# Out:
#        SNo       Date    StartupName            IndustryVertical  \
# 1        1 2017-08-02        Ethinos                  Technology
# 2        2 2017-08-02   Leverage Edu           Consumer Internet
# 11      11 2017-07-06         Minjar                  Technology
# 14      14 2017-07-07    Upwardly.in           Consumer Internet
# 18      18 2017-07-11    Design Cafe           Consumer Internet
# ...    ...        ...            ...                         ...
# 2183  2183 2015-04-23      EazyDiner  Restaurant reservation app
# 2184  2184 2015-04-23  Phone Warrior         Spam Call block App
# 2189  2189 2015-04-27          GIBBS                  Clean Tech
# 2191  2191 2015-04-28   Urban Ladder  Online Furniture ecommerce
# 2197  2197 2015-04-29           Dazo    Mobile Food Ordering app
#
#                                         SubVertical CityLocation  \
# 1                          Digital Marketing Agency       Mumbai
# 2     Online platform for Higher Education Services    New Delhi
# 11                         Cloud Solutions provider    Bangalore
# 14                           MF investment platform    Bangalore
# 18                  Online Interior Design platform    Bangalore
# ...                                             ...          ...
# 2183                                         Others    New Delhi
# 2184                                         Others    New Delhi
# 2189                                         Others    New Delhi
# 2191                                         Others    Bangalore
# 2197                                         Others    Bangalore
#
#                                           InvestorsName  InvestmentType  \
# 1                            Triton Investment Advisors  Private Equity
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 11    Blume Ventures, Contrarian Capital India Partn...    Seed Funding
# 14    Sreeram Iyer, Suvo Sarkar, Anita Gupta, Likemi...    Seed Funding
# 18    Fireside Ventures, Apurva Salarpuria, Sidharth...    Seed Funding
# ...                                                 ...             ...
# 2183                 Deepak Shahdadpuri, Gulpreet Kohli    Seed Funding
# 2184                                Lightspeed Ventures    Seed Funding
# 2189                               Infuse Ventures fund  Private Equity
# 2191                 Anand Rajaraman, Venky Harinarayan  Private Equity
# 2197  Sumit Jain, Aprameya Radhakrishna, Alok Goel, ...    Seed Funding
#
#       AmountInUSD       Remarks  month  day  year
# 1               0        Others      8    2  2017
# 2               0        Others      8    2  2017
# 11              0        Others      7    6  2017
# 14              0        Others      7    7  2017
# 18              0        Others      7   11  2017
# ...           ...           ...    ...  ...   ...
# 2183            0        Others      4   23  2015
# 2184            0  Pre-Series A      4   23  2015
# 2189            0      Series B      4   27  2015
# 2191            0      Series D      4   28  2015
# 2197            0        Others      4   29  2015
#
# [566 rows x 13 columns]

# %% [markdown]
# ## `DataFrame.at` vs. `DataFrame.loc`

# %%
#df.at[133,['StartupName', 'AmountInUSD']]

# %%
df.at[133,'StartupName']="Zubair Labs"

# %%
df.at[133,'StartupName']
# Out:
# 'Zubair Labs'

# %%
df.loc[133,['StartupName', 'AmountInUSD']]
# Out:
# StartupName    Zubair Labs
# AmountInUSD          50000
# Name: 133, dtype: object

# %%
# %timeit df.at[133,'StartupName']
# Out:
# 3.91 µs ± 273 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit df.loc[133,'StartupName']
# Out:
# 8.25 µs ± 1.08 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ## Joins

# %%
rows1 = df[0:10]
rows2 = df[5:12]
print(rows1.shape)
rows1
table1 = rows1[['SNo', 'Date', 'CityLocation']]
table2 = rows2[['SNo', 'StartupName', 'IndustryVertical', 'InvestmentType']]
print(table1.shape)
table1
# Out:
# (10, 13)
# (10, 3)
#    SNo       Date CityLocation
# 0    0 2017-08-01    Bangalore
# 1    1 2017-08-02       Mumbai
# 2    2 2017-08-02    New Delhi
# 3    3 2017-08-02       Mumbai
# 4    4 2017-08-02    Hyderabad
# 5    5 2017-07-01    Bangalore
# 6    6 2017-07-03    Ahmedabad
# 7    7 2017-07-04      Gurgaon
# 8    8 2017-07-05    Bangalore
# 9    9 2017-07-05        Noida

# %%
print(table2.shape)
table2
# Out:
# (7, 4)
#     SNo       StartupName   IndustryVertical  InvestmentType
# 5     5     Billion Loans  Consumer Internet    Seed Funding
# 6     6  Ecolibriumenergy         Technology  Private Equity
# 7     7             Droom          eCommerce  Private Equity
# 8     8         Jumbotail          eCommerce  Private Equity
# 9     9            Moglix          eCommerce  Private Equity
# 10   10        Timesaverz  Consumer Internet  Private Equity
# 11   11            Minjar         Technology    Seed Funding

# %%
table1.merge(table2, how='right', on='SNo')
# Out:
#    SNo       Date CityLocation       StartupName   IndustryVertical  \
# 0    5 2017-07-01    Bangalore     Billion Loans  Consumer Internet
# 1    6 2017-07-03    Ahmedabad  Ecolibriumenergy         Technology
# 2    7 2017-07-04      Gurgaon             Droom          eCommerce
# 3    8 2017-07-05    Bangalore         Jumbotail          eCommerce
# 4    9 2017-07-05        Noida            Moglix          eCommerce
# 5   10        NaT          NaN        Timesaverz  Consumer Internet
# 6   11        NaT          NaN            Minjar         Technology
#
#    InvestmentType
# 0    Seed Funding
# 1  Private Equity
# 2  Private Equity
# 3  Private Equity
# 4  Private Equity
# 5  Private Equity
# 6    Seed Funding

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by=['CityLocation'])
# Out:
#        SNo       Date     StartupName                    IndustryVertical  \
# 696    696 2016-09-13     ShoeKonnect                           eCommerce
# 619    619 2016-10-13     Shoekonnect                           eCommerce
# 1655  1655 2015-10-12          Gridle  Cloud Based Collaboration platform
# 2112  2112 2015-05-18        Awaaz De   Enterprise Communication Platform
# 1287  1287 2016-02-16        Salebhai                           eCommerce
# ...    ...        ...             ...                                 ...
# 259    259 2017-03-02  Kreate Konnect                          Technology
# 1555  1555 2015-11-11     Gingercrush      Product Customization Platform
# 935    935 2016-06-15      Oneway.cab                   Consumer Internet
# 1251  1251 2016-02-05       DawaiLelo                   Consumer Internet
# 47      47 2017-07-28      Gympik.com                   Consumer Internet
#
#                                             SubVertical CityLocation  \
# 696                          Footwear & Leather B2B App         Agra
# 619                           B2B Marketplace for Shoes         Agra
# 1655                                             Others    Ahmedabad
# 2112                                             Others    Ahmedabad
# 1287   Sweets, Eatables, Handicrafts Online Marketplace    Ahmedabad
# ...                                                 ...          ...
# 259     End-to-End Seller e-commerce solutions Provider     Vadodara
# 1555                                             Others     Vadodara
# 935                                Taxi Rental Platform     Vadodara
# 1251   Healthcare Services & Online Pharmacy Mobile App     Varanasi
# 47    online marketplace for discovering fitness cen...    bangalore
#
#                                           InvestorsName InvestmentType  \
# 696                               Indian Angels Network   Seed Funding
# 619                                Indian Angel Network   Seed Funding
# 1655                                        LetsVenture   Seed Funding
# 2112                                         Samir Shah   Seed Funding
# 1287  Virendra Shekhawat, Deepak Chokhani, Yogesh Pa...   Seed Funding
# ...                                                 ...            ...
# 259                                             Langoor   Seed Funding
# 1555                    TV Mohandas Pai’s family office   Seed Funding
# 935                                Indian Angel Network   Seed Funding
# 1251                              Undisclosed investors   Seed Funding
# 47                                  RoundGlass Partners   Seed Funding
#
#       AmountInUSD Remarks  month  day  year
# 696             0  Others      9   13  2016
# 619             0  Others     10   13  2016
# 1655       100000  Others     10   12  2015
# 2112            0  Others      5   18  2015
# 1287            0  Others      2   16  2016
# ...           ...     ...    ...  ...   ...
# 259             0  Others      3    2  2017
# 1555            0  Others     11   11  2015
# 935        450000  Others      6   15  2016
# 1251        52000  Others      2    5  2016
# 47              0  Others      7   28  2017
#
# [2372 rows x 13 columns]

# %%
df.sort_values(by=['AmountInUSD'],ascending=False)
# Out:
#        SNo       Date   StartupName                        IndustryVertical  \
# 294    294 2017-03-21      Flipkart                               eCommerce
# 158    158 2017-05-18         Paytm                               ECommerce
# 1976  1976 2015-07-28  Flipkart.com                      Online Marketplace
# 1787  1787 2015-09-29         Paytm        E-Commerce & M-Commerce platform
# 1572  1572 2015-11-18           Ola      Car Aggregator & Retail Mobile App
# ...    ...        ...           ...                                     ...
# 394    394 2017-01-14     SecururAX                              Technology
# 1171  1171 2016-03-08      Finomena                              Technology
# 1746  1746 2015-09-15        Mubble         Prepaid Mobile Bill Manager App
# 1169  1169 2016-03-07        Wooplr                               ECommerce
# 1868  1868 2015-08-19       Envoged  pre-owned Luxury online apparel seller
#
#                                SubVertical CityLocation  \
# 294                  ECommerce Marketplace    Bangalore
# 158     Mobile Wallet & ECommerce platform    Bangalore
# 1976                                Others    Bangalore
# 1787                                Others    New Delhi
# 1572                                Others    Bangalore
# ...                                    ...          ...
# 394         Cloud-based solutions provider    Bangalore
# 1171  Credit Worthiness Big Data Analytics    New Delhi
# 1746                                Others    Bangalore
# 1169      Curated Fashion ECommerce portal    Bangalore
# 1868                                Others       Mumbai
#
#                                           InvestorsName  InvestmentType  \
# 294                   Microsoft, eBay, Tencent Holdings  Private Equity
# 158                                      SoftBank Group  Private Equity
# 1976           Steadview Capital and existing investors  Private Equity
# 1787                       Alibaba Group, Ant Financial  Private Equity
# 1572  Baillie Gifford, Falcon Edge Capital, Tiger Gl...  Private Equity
# ...                                                 ...             ...
# 394   Axilor Ventures, Parampara Early Stage Opportu...  Private Equity
# 1171                              Matrix Partners India  Private Equity
# 1746                                    Nandan Nilekani    Seed Funding
# 1169  Naveen Tewari, Abhay Singhal, Amit Gupta, Piyu...    Seed Funding
# 1868   Manish Dhingra, Ankush Nijhawa, Gaurav Bhatnagar    Seed Funding
#
#       AmountInUSD                            Remarks  month  day  year
# 294    1400000000                             Others      3   21  2017
# 158    1400000000                             Others      5   18  2017
# 1976    700000000   Late Stage, 10th Round More here      7   28  2015
# 1787    680000000  Late Stage (Alibaba @ 40% equity)      9   29  2015
# 1572    500000000      Series F ( More Details Here)     11   18  2015
# ...           ...                                ...    ...  ...   ...
# 394             0                             Others      1   14  2017
# 1171            0                             Others      3    8  2016
# 1746            0                             Others      9   15  2015
# 1169            0                             Others      3    7  2016
# 1868            0                             Others      8   19  2015
#
# [2372 rows x 13 columns]

# %% [markdown]
# ## Column / Row Concatenation

# %%
df.columns
# Out:
# Index(['SNo', 'Date', 'StartupName', 'IndustryVertical', 'SubVertical',
#        'CityLocation', 'InvestorsName', 'InvestmentType', 'AmountInUSD',
#        'Remarks', 'month', 'day', 'year'],
#       dtype='object')

# %%
part1 = df[['SNo', 'Date', 'StartupName']]
part2 = df[['InvestorsName', 'InvestmentType']]
print(part1.shape)
part1.head()
# Out:
# (2372, 3)
#    SNo       Date   StartupName
# 0    0 2017-08-01      TouchKin
# 1    1 2017-08-02       Ethinos
# 2    2 2017-08-02  Leverage Edu
# 3    3 2017-08-02          Zepo
# 4    4 2017-08-02  Click2Clinic

# %%
print(part2.shape)
part2.head()
# Out:
# (2372, 2)
#                                        InvestorsName  InvestmentType
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding

# %%
pd.concat([part1, part2], axis=1)
# Out:
#        SNo       Date       StartupName  \
# 0        0 2017-08-01          TouchKin
# 1        1 2017-08-02           Ethinos
# 2        2 2017-08-02      Leverage Edu
# 3        3 2017-08-02              Zepo
# 4        4 2017-08-02      Click2Clinic
# ...    ...        ...               ...
# 2367  2367 2015-01-29        Printvenue
# 2368  2368 2015-01-29          Graphene
# 2369  2369 2015-01-30    Mad Street Den
# 2370  2370 2015-01-30         Simplotel
# 2371  2371 2015-01-31  couponmachine.in
#
#                                           InvestorsName  InvestmentType
# 0                                           Kae Capital  Private Equity
# 1                            Triton Investment Advisors  Private Equity
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3     Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                        Narottam Thudi, Shireesh Palle    Seed Funding
# ...                                                 ...             ...
# 2367                        Asia Pacific Internet Group  Private Equity
# 2368                                     KARSEMVEN Fund  Private Equity
# 2369                     Exfinity Fund, GrowX Ventures.  Private Equity
# 2370                                         MakeMyTrip  Private Equity
# 2371                  UK based Group of Angel Investors    Seed Funding
#
# [2372 rows x 5 columns]

# %% [markdown]
# **Concatenation**
#
#
# concatenate function can be used to concatenate two arrays either row-wise or column-wise. Concatenate function can take two or more arrays of the same shape and by default it concatenates row-wise i.e. axis=0.

# %% [markdown]
# **Concatenate row wise**
# ![Image of Yaktocat](http://www.datasciencemadesimple.com/wp-content/uploads/2017/11/rowbind-in-python-pandas-0.png)

# %% [markdown]
# **Concatenate Column wise**
# ![Image of Yaktocat](http://www.datasciencemadesimple.com/wp-content/uploads/2017/11/column-bind-in-python-pandas-1.png)

# %%
rows1 = df[:3]
rows2 = df[5:7]
print(rows1.shape)
rows1
# Out:
# (3, 13)
#    SNo       Date   StartupName   IndustryVertical  \
# 0    0 2017-08-01      TouchKin         Technology
# 1    1 2017-08-02       Ethinos         Technology
# 2    2 2017-08-02  Leverage Edu  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
#
#    AmountInUSD Remarks  month  day  year
# 0      1300000  Others      8    1  2017
# 1            0  Others      8    2  2017
# 2            0  Others      8    2  2017

# %%
print(rows2.shape)
rows2
# Out:
# (2, 13)
#    SNo       Date       StartupName   IndustryVertical  \
# 5    5 2017-07-01     Billion Loans  Consumer Internet
# 6    6 2017-07-03  Ecolibriumenergy         Technology
#
#                             SubVertical CityLocation  \
# 5         Peer to Peer Lending platform    Bangalore
# 6  Energy management solutions provider    Ahmedabad
#
#                               InvestorsName  InvestmentType  AmountInUSD  \
# 5  Reliance Corporate Advisory Services Ltd    Seed Funding      1000000
# 6                      Infuse Ventures, JLL  Private Equity      2600000
#
#   Remarks  month  day  year
# 5  Others      7    1  2017
# 6  Others      7    3  2017

# %%
pd.concat([rows1, rows2], axis=0)
# Out:
#    SNo       Date       StartupName   IndustryVertical  \
# 0    0 2017-08-01          TouchKin         Technology
# 1    1 2017-08-02           Ethinos         Technology
# 2    2 2017-08-02      Leverage Edu  Consumer Internet
# 5    5 2017-07-01     Billion Loans  Consumer Internet
# 6    6 2017-07-03  Ecolibriumenergy         Technology
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 5                  Peer to Peer Lending platform    Bangalore
# 6           Energy management solutions provider    Ahmedabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 5           Reliance Corporate Advisory Services Ltd    Seed Funding
# 6                               Infuse Ventures, JLL  Private Equity
#
#    AmountInUSD Remarks  month  day  year
# 0      1300000  Others      8    1  2017
# 1            0  Others      8    2  2017
# 2            0  Others      8    2  2017
# 5      1000000  Others      7    1  2017
# 6      2600000  Others      7    3  2017
