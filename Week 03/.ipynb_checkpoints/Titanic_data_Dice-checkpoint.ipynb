# %% [markdown]
# <center><font size="16">**Titanic: Machine Learning from Disaster**</font></center>

# %% [markdown]
# The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this notebook, we will see how to dig deep into the data and visualize it.

# %% [markdown]
#  [![TITANIC sinking](https://i.imgur.com/8Rmg0vy.jpg)](https://youtu.be/9xoqXVjBEF8 "TITANIC sinking")

# %% [markdown]
# ### Data

# %% [markdown]
# The data has been split into two groups:
#
# - titanic data (titanic_data.csv)
# - competition data (competition.csv)
#
# The tasks given to you will be performed on "competition.csv"

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# <center>
# <table class="table table-bordered">
# <tr>
# <th style="width:5%">Variable</th><th style="width:5%">Definition</th><th style="width:5%">Key</th>
# </tr>
# <tr>
# <td>survival</td>
# <td>Survival</td>
# <td>0 = No, 1 = Yes</td>
# </tr>
# <tr>
# <td>pclass</td>
# <td>Ticket class</td>
# <td>1 = 1st, 2 = 2nd, 3 = 3rd</td>
# </tr>
# <tr>
# <td>sex</td>
# <td>sex</td>
# <td></td>
# </tr>
# <tr>
# <td>Age</td>
# <td>Age in years</td>
# <td></td>
# </tr>
# <tr>
# <td>sibsp</td>
# <td># of siblings / spouses aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>parch</td>
# <td># of parents / children aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>ticket</td>
# <td>Ticket number</td>
# <td></td>
# </tr>
# <tr>
# <td>fare</td>
# <td>Passenger fare</td>
# <td></td>
# </tr>
# <tr>
# <td>cabin</td>
# <td>Cabin number</td>
# <td></td>
# </tr>
# <tr>
# <td>embarked</td>
# <td>Port of Embarkation</td>
# <td>C = Cherbourg, Q = Queenstown, S = Southampton</td>
# </tr>
# </table>
# </center>

# %% [markdown]
# # <mark>Wrangling & EDA</mark>

# %% [markdown]
# # 1. <u>Loading Packages.</u>

# %%
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# # 2. <u>Loading Data & Basic Analysis</u>

# %%
data = pd.read_csv('data/titanic_data.csv')
df = data.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                             Heikkinen, Miss. Laina  female 26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                           Allen, Mr. William Henry    male 35.00      0
#
#    Parch            Ticket  Fare Cabin Embarked
# 0      0         A/5 21171  7.25   NaN        S
# 1      0          PC 17599 71.28   C85        C
# 2      0  STON/O2. 3101282  7.92   NaN        S
# 3      0            113803 53.10  C123        S
# 4      0            373450  8.05   NaN        S

# %%
# Data types
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# basic summary
df.describe()
# Out:
#        PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# count       891.00    891.00  891.00 714.00 891.00 891.00 891.00
# mean        446.00      0.38    2.31  29.70   0.52   0.38  32.20
# std         257.35      0.49    0.84  14.53   1.10   0.81  49.69
# min           1.00      0.00    1.00   0.42   0.00   0.00   0.00
# 25%         223.50      0.00    2.00  20.12   0.00   0.00   7.91
# 50%         446.00      0.00    3.00  28.00   0.00   0.00  14.45
# 75%         668.50      1.00    3.00  38.00   1.00   0.00  31.00
# max         891.00      1.00    3.00  80.00   8.00   6.00 512.33

# %%
# basic summary of object types
df.describe(include=["O"])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# null vlaues counts
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 3. <u>Exploration</u>
# > #### <u>3.1 Exploration of Complete & Important Variables</u>
#
#     Our response variable in the training set is complete, as well as Sex and Pclass, which seem two of the most important dependent variables.

# %% [markdown]
# **Survival**

# %%
ax sns.catplot(x='Survived', data=df, hue='Survived', kind='count' )
ax1 ax.facet_axis(0, 0)
for c in ax1.containers:
    ax1.bar_label(c, fontsize=13)
plt.title('People Survived');
plt.yticks(range(0,600,50));

# %% [markdown]
# > ###  <u>Gender & Survival</u>

# %%
plt.subplots(figsize=(15,5), sharey=True )
ax1=plt.subplot(1,2,2)
ax1=sns.countplot('Sex',hue='Survived',data=df); 
ax1.set_title('Passenger Survived w.r.t to gender')
plt.yticks(range(0,700,50));
for container in ax1.containers:
    plt.bar_label(container, fontsize=13)   
ax2=plt.subplot(1,2,1)
ax1 =sns.countplot('Sex',data=df);
ax1.set_title('Total passenger and gender')
plt.yticks(range(0,700,50));
for container in ax1.containers:
    plt.bar_label(container, fontsize=13)   
plt.suptitle('Gender Survival', size=16);

# %% [markdown]
# > ### <u>Passenger Survival Class</u>

# %%
plt.subplots(figsize=(15,5),sharey=True )
ax1=plt.subplot(1,2,2)
ax1 = sns.countplot('Pclass',hue='Survived',data=df); 
ax1.set_title('Passenger Survived in Class')
plt.yticks(range(0,600,50));
for container in ax1.containers:
    plt.bar_label(container)    
ax2=plt.subplot(1,2,1)
ax1 = sns.countplot('Pclass',data=df);
ax1.set_title('Total passenger in Class')
plt.yticks(range(0,600,50));
for container in ax1.containers:
    plt.bar_label(container)    
plt.suptitle('Passenger Survival Class');

# %% [markdown]
# > ### Passenger Class, Gender & Survival

# %%
ax1=sns.catplot('Sex',col='Pclass',data=df,kind='count');
plt.suptitle('Passenger Class, Gender & Survival');
plt.yticks(range(0,400,25));
for col in range(3):
    ax = ax1.facet_axis(0, col)
    for c in ax.containers:
        ax.bar_label(c, fontsize=13)
ax2 =sns.catplot('Sex',col='Pclass',hue='Survived',data=df,kind='count',legend=False);
for col in range(3):
    ax = ax2.facet_axis(0, col)
    for c in ax.containers:
        ax.bar_label(c, fontsize=13)    
plt.legend(loc=0)
plt.yticks(range(0,350,25));
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 3.2 What's in the name?

# %% [markdown]
# **Extracting & Analyzing Titles**

# %% [markdown]
# This is called feature engineering where you derive additional columns as per your domain knowledge like creating 'Title in the following example.

# %% [markdown]
# The term *Mademoiselle* is a French familiar title, abbreviated **Mlle**, traditionally given to an unmarried woman. The equivalent in English is "Miss". However, the courtesy title "Madame" is accorded women where their marital status is unknown.

# %%
import re
df['Title'] =df['Name'].apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                             Heikkinen, Miss. Laina  female 26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                           Allen, Mr. William Henry    male 35.00      0
#
#    Parch            Ticket  Fare Cabin Embarked Title
# 0      0         A/5 21171  7.25   NaN        S    Mr
# 1      0          PC 17599 71.28   C85        C   Mrs
# 2      0  STON/O2. 3101282  7.92   NaN        S  Miss
# 3      0            113803 53.10  C123        S   Mrs
# 4      0            373450  8.05   NaN        S    Mr

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x='Title', data=df,
                  order=df['Title'].value_counts(ascending=True).index);
ax.set_title('Title Counts')
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# In France, one traditionally calls a young, unmarried woman Mademoiselle – Mlle for short – and an older, married woman _Madame_, whose abbreviation is **Mme**.

# %%
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')

# %%
df.loc[(~df['Title'].isin(['Mr', 'Mrs', 'Miss', 'Master'])), 'Title'] = 'Rare Title'

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(x='Title', data=df,
                  order=df['Title'].value_counts(ascending=True).index);
ax.set_title('Title Counts: Update')
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.subplots(figsize=(15,5), sharey=True )
ax1=plt.subplot(1,2,1)
plt.title('Title with respect to pclass')
ax1 = sns.histplot(data=df, x="Title", hue="Pclass", multiple="stack", shrink=.8)
for c in ax1.containers:
    ax1.bar_label(c, label_type='center',fontsize=13)
ax2=plt.subplot(1,2,2)
plt.title('Title with respect to survival', fontsize=16)
ax2 = sns.histplot(data=df, x="Title", hue="Survived", multiple="stack", shrink=.8)
for c in ax2.containers:
    ax2.bar_label(c, label_type='center',fontsize=13)

# %% [markdown]
# ### 3.3 Travelling Alone vs. Travelling in groups

# %% [markdown]
# **3.3.1 Family Size**

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                             Heikkinen, Miss. Laina  female 26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                           Allen, Mr. William Henry    male 35.00      0
#
#    Parch            Ticket  Fare Cabin Embarked Title
# 0      0         A/5 21171  7.25   NaN        S    Mr
# 1      0          PC 17599 71.28   C85        C   Mrs
# 2      0  STON/O2. 3101282  7.92   NaN        S  Miss
# 3      0            113803 53.10  C123        S   Mrs
# 4      0            373450  8.05   NaN        S    Mr

# %%
# Combine all family members
df['Fsize'] = df['SibSp'] + df['Parch']+1

# %%
plt.subplots(figsize=(9,6))
plt.suptitle('Travelling Alone vs. Travelling in groups',y=1, size=16)
ax1 = plt.subplot(1,2,1)
plt.title('Families Size count', fontsize=14)
ax1 = sns.countplot(data=df, x='Fsize')
for cont in ax1.containers:
    plt.bar_label(cont, fontsize=13 )
df= df.sort_values(by=["Fsize"])
df['Fsize_temp'] = df['Fsize'].astype('str')
ax2 = plt.subplot(1,2,2)
plt.title('Families Size w.r.t survival', fontsize=14)
sns.histplot(data=df, x="Fsize_temp", hue="Survived", multiple="stack",shrink=.99)
for cont in ax2.containers:
    plt.bar_label(cont)
df.drop(['Fsize_temp'], axis = 1, inplace = True)

# %%
temp = df.groupby('Fsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')
plt.figure(figsize=(10,6));
ax = sns.barplot(data=temp,x='Fsize', y='Perc', hue='Survived', dodge=True);
for cont in ax.containers:
    plt.bar_label(cont,fmt='%.1f')

# %% [markdown]
# **3.3.2 How many people booked together?**
#
# _Apart from families, there could be groups of friends travelling together._

# %% [markdown]
# **reset_index()** is a method to reset index of a Data Frame. **reset_index()** method sets a list of integer ranging from 0 to length of data as index.

# %%
df.Ticket.nunique()
# Out:
# 681

# %%
df['Ticket'].value_counts().reset_index()
# Out:
#          index  Ticket
# 0     CA. 2343       7
# 1       347082       7
# 2         1601       7
# 3      CA 2144       6
# 4       347088       6
# ..         ...     ...
# 676     350035       1
# 677  C.A. 6212       1
# 678     349224       1
# 679  A/4 45380       1
# 680     330959       1
#
# [681 rows x 2 columns]

# %%
temp = df['Ticket'].value_counts().reset_index(name='Tsize')
temp
# Out:
#          index  Tsize
# 0     CA. 2343      7
# 1       347082      7
# 2         1601      7
# 3      CA 2144      6
# 4       347088      6
# ..         ...    ...
# 676     350035      1
# 677  C.A. 6212      1
# 678     349224      1
# 679  A/4 45380      1
# 680     330959      1
#
# [681 rows x 2 columns]

# %%
df = df.merge(temp, left_on='Ticket', right_on='index',how='inner').drop('index', axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass                                      Name  \
# 0          891         0       3                       Dooley, Mr. Patrick
# 1          681         0       3                       Peters, Miss. Katie
# 2          682         1       1                        Hassab, Mr. Hammad
# 3          646         1       1                 Harper, Mr. Henry Sleeper
# 4           53         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
#
#       Sex   Age  SibSp  Parch    Ticket  Fare Cabin Embarked Title  Fsize  \
# 0    male 32.00      0      0    370376  7.75   NaN        Q    Mr      1
# 1  female   NaN      0      0    330935  8.14   NaN        Q  Miss      1
# 2    male 27.00      0      0  PC 17572 76.73   D49        C    Mr      1
# 3    male 48.00      1      0  PC 17572 76.73   D33        C    Mr      2
# 4  female 49.00      1      0  PC 17572 76.73   D33        C   Mrs      2
#
#    Tsize
# 0      1
# 1      1
# 2      3
# 3      3
# 4      3

# %% [markdown]
# **Task 14:**
# Show the countplot on column **'Tsize'** and check how many people are survived and died.

# %%
plt.figure(figsize=(8,6))
plt.title("Ticket Size Vs Survived", fontsize=14)
ax=sns.countplot(data=df, x='Tsize', hue='Survived')
for val in ax.containers:
    plt.bar_label(val)

# %%
temp = df.groupby('Tsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')

# %%
plt.figure(figsize=(8,6))
ax =sns.barplot(x='Tsize', y='Perc', hue='Survived', data=temp, dodge=True);
plt.title("Ticket Size Vs Survived ratio")
for cont in ax.containers:
    plt.bar_label(cont, fmt='%.1f')

# %% [markdown]
# **3.3.3 Consolidating family & friends**

# %%
df['Group'] = df[['Tsize', 'Fsize']].max(axis=1)
sns.countplot(x='Group', hue='Survived', data=df);

# %%
df['GrpSize'] = ''
df.loc[df['Group']==1, 'GrpSize'] = df.loc[df['Group']==1, 'GrpSize'].replace('', 'solo')
df.loc[df['Group']==2, 'GrpSize'] = df.loc[df['Group']==2, 'GrpSize'].replace('', 'couple')
df.loc[(df['Group']<=4) & (df['Group']>=3), 'GrpSize'] = df.loc[(df['Group']<=4) & (df['Group']>=3), 'GrpSize'].replace('', 'group')
df.loc[df['Group']>4, 'GrpSize'] = df.loc[df['Group']>4, 'GrpSize'].replace('', 'large group')
df.head()
# Out:
#    PassengerId  Survived  Pclass                                      Name  \
# 0          891         0       3                       Dooley, Mr. Patrick
# 1          681         0       3                       Peters, Miss. Katie
# 2          682         1       1                        Hassab, Mr. Hammad
# 3          646         1       1                 Harper, Mr. Henry Sleeper
# 4           53         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
#
#       Sex   Age  SibSp  Parch    Ticket  Fare Cabin Embarked Title  Fsize  \
# 0    male 32.00      0      0    370376  7.75   NaN        Q    Mr      1
# 1  female   NaN      0      0    330935  8.14   NaN        Q  Miss      1
# 2    male 27.00      0      0  PC 17572 76.73   D49        C    Mr      1
# 3    male 48.00      1      0  PC 17572 76.73   D33        C    Mr      2
# 4  female 49.00      1      0  PC 17572 76.73   D33        C   Mrs      2
#
#    Tsize  Group GrpSize
# 0      1      1    solo
# 1      1      1    solo
# 2      3      3   group
# 3      3      3   group
# 4      3      3   group

# %%
plt.figure(figsize=(10,6));
plt.title('Group Survival Rate', fontsize=14)
ax = sns.countplot(x='GrpSize', order=['solo', 'couple', 'group', 'large group'], hue='Survived', data=df);

# %% [markdown]
# Applying the same categories for groups on 'dfcomp'

# %% [markdown]
# ### 3.4 Effect of Fare

# %% [markdown]
# **Task 16:**
# Check the null values of fare

# %%
df.Fare.isnull().sum()
# Out:
# 0

# %%
plt.subplots(figsize=(15,6))
sns.histplot(df['Fare']);

# %%
df.loc[(df['Fare'] == 0) & (df['Pclass'] == 1), 'Fare'] = df[df['Pclass'] == 1]['Fare'].median()
df.loc[(df['Fare'] == 0) & (df['Pclass'] == 2), 'Fare'] = df[df['Pclass'] == 2]['Fare'].median()
df.loc[(df['Fare'] == 0) & (df['Pclass'] == 3), 'Fare'] = df[df['Pclass'] == 3]['Fare'].median()

# %%
df[df['Fare']==0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title, Fsize, Tsize, Group, GrpSize]
# Index: []

# %%
df['FareCat'] = ''
df.loc[df['Fare']<=10, 'FareCat'] = '0-10'
df.loc[(df['Fare']>10) & (df['Fare']<=25), 'FareCat'] = '10-25'
df.loc[(df['Fare']>25) & (df['Fare']<=40), 'FareCat'] = '25-40'
df.loc[(df['Fare']>40) & (df['Fare']<=70), 'FareCat'] = '40-70'
df.loc[(df['Fare']>70) & (df['Fare']<=100), 'FareCat'] = '70-100'
df.loc[df['Fare']>100, 'FareCat'] = '100+'
df[['Fare', 'FareCat']].head()
# Out:
#    Fare FareCat
# 0  7.75    0-10
# 1  8.14    0-10
# 2 76.73  70-100
# 3 76.73  70-100
# 4 76.73  70-100

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='FareCat', order=['0-10', '10-25', '25-40', '40-70', '70-100', '100+'], hue='Survived', data=df);

# %%
df= df.sort_values(by=["Fare"])
plt.subplots(figsize=(13,8))
plt.suptitle('Fare distribution');
ax1 = plt.subplot(1,2,1)
plt.title('Fare cat. histogram')
ax1 = sns.countplot(data=df, x='FareCat')
for cont in ax1.containers:
    plt.bar_label(cont)
ax2 = plt.subplot(1,2,2)
plt.title('Fare cat w.r.t survival', fontsize=14)
sns.histplot(data=df, x="FareCat", hue="Survived", multiple="stack",shrink=.99)
for cont in ax2.containers:
    plt.bar_label(cont)

# %% [markdown]
# ### 3.5 Effect of Embarked variable
#
# _C = Cherbourg(France), Q = Queenstown(Ireland), S = Southampton(England)_

# %%
# Write the code here
sns.countplot(data=df, x = 'Embarked', hue = 'Survived' )
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ***Engineered Features***

# %%
df.head(2)
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 24           379         0       3       Betros, Mr. Tannous  male 20.00
# 418          873         0       1  Carlsson, Mr. Frans Olof  male 33.00
#
#      SibSp  Parch Ticket  Fare        Cabin Embarked Title  Fsize  Tsize  \
# 24       0      0   2648  4.01          NaN        C    Mr      1      1
# 418      0      0    695  5.00  B51 B53 B55        S    Mr      1      1
#
#      Group GrpSize FareCat
# 24       1    solo    0-10
# 418      1    solo    0-10

# %% [markdown]
# ## 4. Missing Values

# %% [markdown]
# ### 4.1 Age

# %%
df.Age.isnull().sum()
# Out:
# 177

# %%
sns.histplot(data=df, x="Age", bins=30)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(10,6));
sns.kdeplot(df[df['Survived'] == 0]['Age'].dropna(), shade=True,label="Not survived");
sns.kdeplot(df[df['Survived'] == 1]['Age'].dropna(), shade=True,label="Survived");
plt.legend()

# %%
temp = df[df['Age'].isnull() == False]

# %%
sns.set_context('poster')
sns.catplot(kind='box', x='Age', col='Title', row='Pclass', data=temp);

# %%
for t in df['Title'].unique():
    for p in df['Pclass'].unique():
        df.loc[(df['Title'] == t) & (df['Pclass'] == p) & (df['Age'].isnull()), 'Age'] = df.loc[(df['Title'] == t) & (df['Pclass'] == p), 'Age'].median()

# %%
plt.figure(figsize=(10,6));
sns.kdeplot(df[df['Survived'] == 0]['Age'].dropna(), shade=True,label="Not survived");
sns.kdeplot(df[df['Survived'] == 1]['Age'].dropna(), shade=True,label="Survived");
plt.legend()

# %% [markdown]
# Creating Age categories

# %%
df['AgeCat']=''
df.loc[ df['Age'] <= 16, 'AgeCat'] = '0-16'
df.loc[(df['Age'] > 16) & (df['Age'] <= 32), 'AgeCat'] = '16-32'
df.loc[(df['Age'] > 32) & (df['Age'] <= 48), 'AgeCat'] = '32-48'
df.loc[(df['Age'] > 48) & (df['Age'] <= 64), 'AgeCat'] = '48-64'
df.loc[ df['Age'] > 64, 'AgeCat']= '64+'

# %%
df.head()
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 24           379         0       3               Betros, Mr. Tannous  male
# 418          873         0       1          Carlsson, Mr. Frans Olof  male
# 163          327         0       3         Nysveen, Mr. Johan Hansen  male
# 435          844         0       3        Lemberopolous, Mr. Peter L  male
# 379          819         0       3  Holm, Mr. John Fredrik Alexander  male
#
#       Age  SibSp  Parch  Ticket  Fare        Cabin Embarked Title  Fsize  \
# 24  20.00      0      0    2648  4.01          NaN        C    Mr      1
# 418 33.00      0      0     695  5.00  B51 B53 B55        S    Mr      1
# 163 61.00      0      0  345364  6.24          NaN        S    Mr      1
# 435 34.50      0      0    2683  6.44          NaN        C    Mr      1
# 379 43.00      0      0  C 7075  6.45          NaN        S    Mr      1
#
#      Tsize  Group GrpSize FareCat AgeCat
# 24       1      1    solo    0-10  16-32
# 418      1      1    solo    0-10  32-48
# 163      1      1    solo    0-10  48-64
# 435      1      1    solo    0-10  32-48
# 379      1      1    solo    0-10  32-48

# %% [markdown]
# **Task 21:**
# Check if there is any null in the column 'Age'

# %%
df.Age.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 4.2 Embarkment and null values

# %%
df.describe(include='O')
# Out:
#                        Name   Sex    Ticket    Cabin Embarked Title GrpSize  \
# count                   891   891       891      204      889   891     891
# unique                  891     2       681      147        3     5       4
# top     Betros, Mr. Tannous  male  CA. 2343  B96 B98        S    Mr    solo
# freq                      1   577         7        4      644   517     462
#
#        FareCat AgeCat
# count      891    891
# unique       6      5
# top       0-10  16-32
# freq       325    490

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
sns.set_context('notebook')
plt.figure(figsize=(10,6));
plt.title('Embarkment histogram', fontsize=16)
ax = sns.histplot(data=df, x = 'Embarked' );
for mask in ax.containers:
    plt.bar_label(mask)

# %%
df.loc[(df['Embarked'].isnull()),'Embarked']='S'

# %% [markdown]
# ### 4.3 Dropping Cabin

# %% [markdown]
# Defining the cabin type

# %%
df.Cabin.isnull().sum()/df.shape[0]*100 #null percentage
# Out:
# 77.10437710437711

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.isnull().sum() # All set, no zeros
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Title          0
# Fsize          0
# Tsize          0
# Group          0
# GrpSize        0
# FareCat        0
# AgeCat         0
# dtype: int64

# %% [markdown]
# Dropping Cabin

# %% [markdown]
# ## 5. Feature Selection

# %%
df.head()
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 24           379         0       3               Betros, Mr. Tannous  male
# 418          873         0       1          Carlsson, Mr. Frans Olof  male
# 163          327         0       3         Nysveen, Mr. Johan Hansen  male
# 435          844         0       3        Lemberopolous, Mr. Peter L  male
# 379          819         0       3  Holm, Mr. John Fredrik Alexander  male
#
#       Age  SibSp  Parch  Ticket  Fare Embarked Title  Fsize  Tsize  Group  \
# 24  20.00      0      0    2648  4.01        C    Mr      1      1      1
# 418 33.00      0      0     695  5.00        S    Mr      1      1      1
# 163 61.00      0      0  345364  6.24        S    Mr      1      1      1
# 435 34.50      0      0    2683  6.44        C    Mr      1      1      1
# 379 43.00      0      0  C 7075  6.45        S    Mr      1      1      1
#
#     GrpSize FareCat AgeCat
# 24     solo    0-10  16-32
# 418    solo    0-10  32-48
# 163    solo    0-10  48-64
# 435    solo    0-10  32-48
# 379    solo    0-10  32-48

# %%
cor = df[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Embarked', 'Title', 'Fsize', 'Tsize',
       'Group', 'GrpSize', 'FareCat', 'AgeCat']]
sns.set_context('notebook')
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (10,7)
corr = cor.corr().round(2)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
mask = np.zeros_like(corr,dtype=bool)
mask[np.triu_indices_from(mask)]=True
corr[mask]=np.nan
(corr.style.background_gradient(cmap='coolwarm',axis=None,vmin=-1,vmax=1)
 .highlight_null(null_color='#f1f1f1') 
 .set_precision(1))
sns.heatmap(corr,cmap="coolwarm",annot=True,linewidths=0.5,linecolor='#f1f1f1')
# Out:
# C:\Users\Khan\AppData\Local\Temp\ipykernel_11324\497482004.py:18: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   (corr.style.background_gradient(cmap='coolwarm',axis=None,vmin=-1,vmax=1)
# <AxesSubplot:>

# %%
sns.set_context('poster')
plt.figure(figsize=(15,6))
cor = dftitanic.drop('PassengerId',axis=1).corr()
sns.heatmap(cor, annot=True, fmt='.1g');

# %% [markdown]
# The above heat map shows the corelation of different columns with eachother. A heatmap often helps to view the corelation as seen above. Looking at the above heatmap we can conclude that which attributes or columns are corelated and and can be removed to get a better shaped dataset.
#
# The following points are to be considered for dropping the columns
#
# - **'Group'** holds a corelation of 0.9 with **'Fsize'** and **'Tsize'**. So we will remove **'Group'** and **'Tsize'** because related data can be found in **'GrpSize'**.
# - **'Fsize'** still has a corelation of 0.9  with **'SibSp'** and 0.8 with **'Parch'**.So we will remove 'Fsize' because **'SibSp'** and **'Parch'** are providing the required information.
# - The **'Name'** column can also be removed because **'Title'** has been extracted.
# - Similarly **'Age'** and **'Fare'** can also be removed because **'AgeCat'** and **'FareCat'** provide the related information.
#
# So the final columns to be dropped are: 'Name','Age','Fare','Ticket','Fsize','Tsize' and 'Group'

# %%
drop_features = ['Name','Age','Fare','Ticket','Fsize','Tsize','Group']

# %% [markdown]
# Selecting final features

# %%
df.drop(drop_features,axis=1,inplace=True)

# %% [markdown]
# Exporting final dataset in csv file

# %%
df.to_csv('data/titanic_clean.csv',index=False)
